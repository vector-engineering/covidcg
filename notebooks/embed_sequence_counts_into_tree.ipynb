# %% [markdown]
# # Find a way to embed sequence count information into the location tree

# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('/Volumes/GoogleDrive/My Drive/covid_data/taxon_locations.csv')
df
# Out:
#                                    name       gisaid_id sample_date  \
# 0       hCoV-19/Algeria/G0640_2265/2020  EPI_ISL_418242  2020-03-08
# 1       hCoV-19/Algeria/G0638_2264/2020  EPI_ISL_418241  2020-03-02
# 2       hCoV-19/Algeria/G0860_2262/2020  EPI_ISL_420037  2020-03-02
# 3                  hCoV-19/DRC/431/2020  EPI_ISL_420847  2020-03-26
# 4                 hCoV-19/DRC/3089/2020  EPI_ISL_437358  2020-04-19
# ...                                 ...             ...         ...
# 37392  hCoV-19/Uruguay/UY-NYUMC859/2020  EPI_ISL_457955  2020-03-24
# 37393  hCoV-19/Uruguay/UY-NYUMC858/2020  EPI_ISL_457954  2020-03-23
# 37394  hCoV-19/Uruguay/UY-NYUMC857/2020  EPI_ISL_457953  2020-03-23
# 37395  hCoV-19/Uruguay/UY-NYUMC877/2020  EPI_ISL_457973  2020-04-22
# 37396  hCoV-19/Uruguay/UY-NYUMC845/2020  EPI_ISL_457941  2020-03-17
#
#        location_id         region                           country  \
# 0                0         Africa                           Algeria
# 1                1         Africa                           Algeria
# 2                1         Africa                           Algeria
# 3                2         Africa  Democratic Republic of the Congo
# 4                3         Africa  Democratic Republic of the Congo
# ...            ...            ...                               ...
# 37392         1010  South America                           Uruguay
# 37393         1010  South America                           Uruguay
# 37394         1010  South America                           Uruguay
# 37395         1010  South America                           Uruguay
# 37396         1010  South America                           Uruguay
#
#          division location
# 0           Blida       -1
# 1        Boufarik       -1
# 2        Boufarik       -1
# 3              -1       -1
# 4        Kinshasa       -1
# ...           ...      ...
# 37392  Montevideo       -1
# 37393  Montevideo       -1
# 37394  Montevideo       -1
# 37395  Montevideo       -1
# 37396  Montevideo       -1
#
# [37397 rows x 8 columns]

# %%
df.loc[df['region'] == '-1', 'region'] = None
df.loc[df['country'] == '-1', 'country'] = None
df.loc[df['division'] == '-1', 'division'] = None
df.loc[df['location'] == '-1', 'location'] = None
df
# Out:
#                                    name       gisaid_id sample_date  \
# 0       hCoV-19/Algeria/G0640_2265/2020  EPI_ISL_418242  2020-03-08
# 1       hCoV-19/Algeria/G0638_2264/2020  EPI_ISL_418241  2020-03-02
# 2       hCoV-19/Algeria/G0860_2262/2020  EPI_ISL_420037  2020-03-02
# 3                  hCoV-19/DRC/431/2020  EPI_ISL_420847  2020-03-26
# 4                 hCoV-19/DRC/3089/2020  EPI_ISL_437358  2020-04-19
# ...                                 ...             ...         ...
# 37392  hCoV-19/Uruguay/UY-NYUMC859/2020  EPI_ISL_457955  2020-03-24
# 37393  hCoV-19/Uruguay/UY-NYUMC858/2020  EPI_ISL_457954  2020-03-23
# 37394  hCoV-19/Uruguay/UY-NYUMC857/2020  EPI_ISL_457953  2020-03-23
# 37395  hCoV-19/Uruguay/UY-NYUMC877/2020  EPI_ISL_457973  2020-04-22
# 37396  hCoV-19/Uruguay/UY-NYUMC845/2020  EPI_ISL_457941  2020-03-17
#
#        location_id         region                           country  \
# 0                0         Africa                           Algeria
# 1                1         Africa                           Algeria
# 2                1         Africa                           Algeria
# 3                2         Africa  Democratic Republic of the Congo
# 4                3         Africa  Democratic Republic of the Congo
# ...            ...            ...                               ...
# 37392         1010  South America                           Uruguay
# 37393         1010  South America                           Uruguay
# 37394         1010  South America                           Uruguay
# 37395         1010  South America                           Uruguay
# 37396         1010  South America                           Uruguay
#
#          division location
# 0           Blida     None
# 1        Boufarik     None
# 2        Boufarik     None
# 3            None     None
# 4        Kinshasa     None
# ...           ...      ...
# 37392  Montevideo     None
# 37393  Montevideo     None
# 37394  Montevideo     None
# 37395  Montevideo     None
# 37396  Montevideo     None
#
# [37397 rows x 8 columns]

# %%
# Count sequences per region
dict(df.groupby('region')['gisaid_id'].count())
# Out:
# {'Africa': 359,
#  'Asia': 3038,
#  'Europe': 23941,
#  'North America': 7431,
#  'Oceania': 2146,
#  'South America': 482}

# %%
# Count sequences by region & country
dict(df.groupby(['region', 'country'])['gisaid_id'].count())
# Out:
# {('Africa', 'Algeria'): 3,
#  ('Africa', 'Democratic Republic of the Congo'): 133,
#  ('Africa', 'Egypt'): 2,
#  ('Africa', 'Gambia'): 3,
#  ('Africa', 'Ghana'): 15,
#  ('Africa', 'Kenya'): 112,
#  ('Africa', 'Nigeria'): 17,
#  ('Africa', 'Senegal'): 23,
#  ('Africa', 'South Africa'): 31,
#  ('Africa', 'Uganda'): 20,
#  ('Asia', 'Bangladesh'): 24,
#  ('Asia', 'Brunei'): 5,
#  ('Asia', 'China'): 805,
#  ('Asia', 'Georgia'): 15,
#  ('Asia', 'Hong Kong'): 140,
#  ('Asia', 'India'): 561,
#  ('Asia', 'Indonesia'): 19,
#  ('Asia', 'Iran'): 34,
#  ('Asia', 'Israel'): 222,
#  ('Asia', 'Japan'): 123,
#  ('Asia', 'Jordan'): 28,
#  ('Asia', 'Kazakhstan'): 53,
#  ('Asia', 'Kuwait'): 8,
#  ('Asia', 'Lebanon'): 11,
#  ('Asia', 'Malaysia'): 22,
#  ('Asia', 'Myanmar'): 1,
#  ('Asia', 'Oman'): 35,
#  ('Asia', 'Pakistan'): 4,
#  ('Asia', 'Philippines'): 13,
#  ('Asia', 'Qatar'): 16,
#  ('Asia', 'Saudi Arabia'): 130,
#  ('Asia', 'Singapore'): 148,
#  ('Asia', 'South Korea'): 29,
#  ('Asia', 'Sri Lanka'): 6,
#  ('Asia', 'Taiwan'): 105,
#  ('Asia', 'Thailand'): 386,
#  ('Asia', 'Timor-Leste'): 17,
#  ('Asia', 'Turkey'): 1,
#  ('Asia', 'United Arab Emirates'): 25,
#  ('Asia', 'Uzbekistan'): 2,
#  ('Asia', 'Vietnam'): 50,
#  ('Europe', 'Austria'): 250,
#  ('Europe', 'Belarus'): 3,
#  ('Europe', 'Belgium'): 537,
#  ('Europe', 'Croatia'): 20,
#  ('Europe', 'Czechia'): 30,
#  ('Europe', 'Denmark'): 742,
#  ('Europe', 'Estonia'): 19,
#  ('Europe', 'Finland'): 39,
#  ('Europe', 'France'): 386,
#  ('Europe', 'Germany'): 208,
#  ('Europe', 'Greece'): 101,
#  ('Europe', 'Hungary'): 32,
#  ('Europe', 'Iceland'): 601,
#  ('Europe', 'Ireland'): 18,
#  ('Europe', 'Italy'): 124,
#  ('Europe', 'Latvia'): 25,
#  ('Europe', 'Lithuania'): 3,
#  ('Europe', 'Luxembourg'): 257,
#  ('Europe', 'Netherlands'): 840,
#  ('Europe', 'Norway'): 48,
#  ('Europe', 'Poland'): 79,
#  ('Europe', 'Portugal'): 643,
#  ('Europe', 'Romania'): 13,
#  ('Europe', 'Russia'): 215,
#  ('Europe', 'Serbia'): 7,
#  ('Europe', 'Slovakia'): 4,
#  ('Europe', 'Slovenia'): 5,
#  ('Europe', 'Spain'): 984,
#  ('Europe', 'Sweden'): 353,
#  ('Europe', 'Switzerland'): 325,
#  ('Europe', 'Turkey'): 64,
#  ('Europe', 'United Kingdom'): 16965,
#  ('Europe', '\u200eRomania'): 1,
#  ('North America', 'Canada'): 207,
#  ('North America', 'Costa Rica'): 6,
#  ('North America', 'Jamaica'): 8,
#  ('North America', 'Mexico'): 29,
#  ('North America', 'Panama'): 1,
#  ('North America', 'USA'): 7180,
#  ('Oceania', 'Australia'): 1888,
#  ('Oceania', 'Guam'): 3,
#  ('Oceania', 'New Zealand'): 255,
#  ('South America', 'Argentina'): 29,
#  ('South America', 'Brazil'): 129,
#  ('South America', 'Chile'): 144,
#  ('South America', 'Colombia'): 129,
#  ('South America', 'Ecuador'): 4,
#  ('South America', 'Peru'): 2,
#  ('South America', 'Uruguay'): 45}

# %%
# Count sequences by region, country, and division
dict(df.groupby(['region', 'country', 'division'])['gisaid_id'].count())
# Out:
# {('Africa', 'Algeria', 'Blida'): 1,
#  ('Africa', 'Algeria', 'Boufarik'): 2,
#  ('Africa', 'Democratic Republic of the Congo', 'Kinshasa'): 130,
#  ('Africa', 'Democratic Republic of the Congo', 'Sud Kivu'): 2,
#  ('Africa', 'Gambia', 'West Coast Region'): 3,
#  ('Africa', 'Ghana', 'Greater Accra'): 15,
#  ('Africa', 'Nigeria', 'Kwara State'): 1,
#  ('Africa', 'Nigeria', 'Lagos'): 1,
#  ('Africa', 'Nigeria', 'Ogun State'): 1,
#  ('Africa', 'Nigeria', 'Osun State'): 11,
#  ('Africa', 'Nigeria', 'Oyo State'): 3,
#  ('Africa', 'Senegal', 'Dakar'): 11,
#  ('Africa', 'Senegal', 'Mbour'): 4,
#  ('Africa', 'Senegal', 'St-Louis'): 1,
#  ('Africa', 'Senegal', 'Thies'): 1,
#  ('Africa', 'Senegal', 'Touba'): 6,
#  ('Africa', 'South Africa', 'Eastern Cape'): 1,
#  ('Africa', 'South Africa', 'Gauteng'): 3,
#  ('Africa', 'South Africa', 'KwaZulu-Natal'): 24,
#  ('Africa', 'South Africa', 'Limpopo'): 1,
#  ('Africa', 'South Africa', 'Mpumalanga'): 1,
#  ('Asia', 'Bangladesh', 'Chattogram'): 7,
#  ('Asia', 'Bangladesh', 'Chuandanga'): 1,
#  ('Asia', 'Bangladesh', 'Dhaka'): 13,
#  ('Asia', 'Bangladesh', 'Jhenaidha'): 1,
#  ('Asia', 'Bangladesh', 'Narayanganj'): 1,
#  ('Asia', 'China', 'Anhui'): 2,
#  ('Asia', 'China', 'Beijing'): 73,
#  ('Asia', 'China', 'Fujian'): 11,
#  ('Asia', 'China', 'Guangdong'): 183,
#  ('Asia', 'China', 'Hubei'): 220,
#  ('Asia', 'China', 'Jiangsu'): 1,
#  ('Asia', 'China', 'Jiangxi'): 34,
#  ('Asia', 'China', 'Shandong'): 8,
#  ('Asia', 'China', 'Shanghai'): 95,
#  ('Asia', 'China', 'Sichuan'): 89,
#  ('Asia', 'China', 'Yunnan'): 5,
#  ('Asia', 'China', 'Zhejiang'): 62,
#  ('Asia', 'Georgia', 'Tbilisi'): 15,
#  ('Asia', 'India', 'Andhra Pradesh'): 2,
#  ('Asia', 'India', 'Assam'): 2,
#  ('Asia', 'India', 'Bihar'): 6,
#  ('Asia', 'India', 'Delhi'): 39,
#  ('Asia', 'India', 'Gujarat'): 143,
#  ('Asia', 'India', 'Haryana'): 11,
#  ('Asia', 'India', 'Jammu and Kashmir'): 1,
#  ('Asia', 'India', 'Karnataka'): 17,
#  ('Asia', 'India', 'Kerala'): 2,
#  ('Asia', 'India', 'Ladakh'): 7,
#  ('Asia', 'India', 'Madhya Pradesh'): 19,
#  ('Asia', 'India', 'Maharashtra'): 88,
#  ('Asia', 'India', 'Odisha'): 46,
#  ('Asia', 'India', 'Punjab'): 1,
#  ('Asia', 'India', 'Rajasthan'): 6,
#  ('Asia', 'India', 'Tamil Nadu'): 19,
#  ('Asia', 'India', 'Telangana'): 62,
#  ('Asia', 'India', 'Uttar Pradesh'): 5,
#  ('Asia', 'India', 'West Bengal'): 52,
#  ('Asia', 'Indonesia', 'Depok'): 1,
#  ('Asia', 'Indonesia', 'Jakarta'): 11,
#  ('Asia', 'Indonesia', 'Surabaya'): 2,
#  ('Asia', 'Indonesia', 'Tangerang'): 4,
#  ('Asia', 'Indonesia', 'West Java'): 1,
#  ('Asia', 'Iran', 'Qom'): 9,
#  ('Asia', 'Iran', 'Semnan'): 1,
#  ('Asia', 'Iran', 'Tehran'): 11,
#  ('Asia', 'Israel', 'Jerusalem District'): 60,
#  ('Asia', 'Israel', 'North District'): 29,
#  ('Asia', 'Israel', 'Ramat Gan'): 2,
#  ('Asia', 'Israel', 'South District'): 71,
#  ('Asia', 'Israel', 'Tel Aviv District'): 52,
#  ('Asia', 'Japan', 'Chiba'): 5,
#  ('Asia', 'Japan', 'Ishikawa'): 2,
#  ('Asia', 'Japan', 'Kanagawa'): 2,
#  ('Asia', 'Japan', 'Kanto'): 24,
#  ('Asia', 'Japan', 'Kochi'): 1,
#  ('Asia', 'Japan', 'Saitama'): 10,
#  ('Asia', 'Japan', 'Tokyo'): 2,
#  ('Asia', 'Jordan', 'Amman'): 26,
#  ('Asia', 'Jordan', 'Irbid'): 2,
#  ('Asia', 'Kazakhstan', 'Nur-Sultan'): 53,
#  ('Asia', 'Kuwait', 'Dasman'): 7,
#  ('Asia', 'Kuwait', 'Hawali'): 1,
#  ('Asia', 'Lebanon', 'Beirut'): 11,
#  ('Asia', 'Malaysia', 'Kuala Lumpur'): 4,
#  ('Asia', 'Malaysia', 'Pahang'): 2,
#  ('Asia', 'Malaysia', 'Selangor'): 10,
#  ('Asia', 'Oman', 'Buraimi'): 1,
#  ('Asia', 'Oman', 'Dakhiliyah'): 1,
#  ('Asia', 'Oman', 'Muscat'): 29,
#  ('Asia', 'Oman', 'North Batinah'): 2,
#  ('Asia', 'Oman', 'South Batinah'): 2,
#  ('Asia', 'Pakistan', 'Gilgit'): 1,
#  ('Asia', 'Pakistan', 'Karachi'): 1,
#  ('Asia', 'Pakistan', 'Khyber Pakhtunkhwa'): 1,
#  ('Asia', 'Philippines', 'Manila'): 6,
#  ('Asia', 'Qatar', 'Doha'): 16,
#  ('Asia', 'Saudi Arabia', 'Jeddah'): 12,
#  ('Asia', 'Saudi Arabia', 'Madinah'): 58,
#  ('Asia', 'Saudi Arabia', 'Makkah'): 57,
#  ('Asia', 'Saudi Arabia', 'Riyadh'): 1,
#  ('Asia', 'Taiwan', 'Kaohsiung'): 2,
#  ('Asia', 'Taiwan', 'Keelung'): 1,
#  ('Asia', 'Taiwan', 'New Taipei City'): 22,
#  ('Asia', 'Taiwan', 'Taipei'): 42,
#  ('Asia', 'Taiwan', 'Taoyuan'): 26,
#  ('Asia', 'Thailand', 'Bangkok'): 130,
#  ('Asia', 'Thailand', 'Nakhonnayok'): 1,
#  ('Asia', 'Thailand', 'Nonthaburi'): 25,
#  ('Asia', 'Thailand', 'Pathum Thani'): 2,
#  ('Asia', 'Thailand', 'Phuket'): 1,
#  ('Asia', 'Thailand', 'Samut Prakarn'): 2,
#  ('Asia', 'Thailand', 'Trang'): 1,
#  ('Asia', 'Turkey', 'Mardin'): 1,
#  ('Asia', 'Vietnam', 'Hanoi'): 29,
#  ('Asia', 'Vietnam', 'Ho Chi Minh City'): 11,
#  ('Asia', 'Vietnam', 'Quangninh'): 2,
#  ('Asia', 'Vietnam', 'Thanhhoa'): 1,
#  ('Asia', 'Vietnam', 'Vinhphuc'): 2,
#  ('Europe', 'Austria', 'Aldrans'): 1,
#  ('Europe', 'Austria', 'Bad Gastein'): 1,
#  ('Europe', 'Austria', 'Burgenland'): 2,
#  ('Europe', 'Austria', 'Elbigenalp'): 1,
#  ('Europe', 'Austria', 'Innsbruck'): 23,
#  ('Europe', 'Austria', 'Ischgl'): 43,
#  ('Europe', 'Austria', 'Kematen In Tirol'): 1,
#  ('Europe', 'Austria', 'Laengenfeld'): 1,
#  ('Europe', 'Austria', 'Matrei am Brenner'): 1,
#  ('Europe', 'Austria', 'Ramsau im Zillertal'): 1,
#  ('Europe', 'Austria', 'Seefeld in Tirol'): 1,
#  ('Europe', 'Austria', 'Sistrans'): 1,
#  ('Europe', 'Austria', 'St. Anton'): 2,
#  ('Europe', 'Austria', 'Steinach am Brenner'): 1,
#  ('Europe', 'Austria', 'Strass im Zillertal'): 1,
#  ('Europe', 'Austria', 'Styria'): 19,
#  ('Europe', 'Austria', 'Tyrol'): 5,
#  ('Europe', 'Austria', 'Vienna'): 119,
#  ('Europe', 'Austria', 'Zams'): 1,
#  ('Europe', 'Belgium', 'Antwerp'): 46,
#  ('Europe', 'Belgium', 'Brussels-Capital Region'): 28,
#  ('Europe', 'Belgium', 'East Flanders'): 69,
#  ('Europe', 'Belgium', 'Flemish Brabant'): 40,
#  ('Europe', 'Belgium', 'Hainaut'): 47,
#  ('Europe', 'Belgium', 'Liege'): 271,
#  ('Europe', 'Belgium', 'Limburg'): 17,
#  ('Europe', 'Belgium', 'Namur'): 5,
#  ('Europe', 'Belgium', 'Walloon Brabant'): 10,
#  ('Europe', 'Belgium', 'West Flanders'): 4,
#  ('Europe', 'Croatia', 'Dubrovnik'): 1,
#  ('Europe', 'Croatia', 'Istria'): 12,
#  ('Europe', 'Croatia', 'Koprivnica'): 1,
#  ('Europe', 'Croatia', 'Osijek'): 1,
#  ('Europe', 'Croatia', 'Pula'): 1,
#  ('Europe', 'Croatia', 'Split'): 2,
#  ('Europe', 'Croatia', 'Varaždin County'): 2,
#  ('Europe', 'Czechia', 'Central Czechia and Prague'): 12,
#  ('Europe', 'Czechia', 'Usti nad Labem'): 1,
#  ('Europe', 'Czechia', 'Vysocina Region'): 1,
#  ('Europe', 'Denmark', 'Copenhagen'): 7,
#  ('Europe', 'Finland', 'Helsinki'): 10,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes'): 85,
#  ('Europe', 'France', 'Bourgogne-Franche-Comté'): 8,
#  ('Europe', 'France', 'Bretagne'): 39,
#  ('Europe', 'France', 'Centre-Val de Loire'): 3,
#  ('Europe', 'France', 'Grand Est'): 11,
#  ('Europe', 'France', 'Hauts-de-France'): 59,
#  ('Europe', 'France', 'Normandie'): 3,
#  ('Europe', 'France', 'Occitanie'): 21,
#  ('Europe', 'France', 'Pays de la Loire'): 1,
#  ('Europe', 'France', 'Île-de-France'): 76,
#  ('Europe', 'Germany', 'Bavaria'): 127,
#  ('Europe', 'Germany', 'Hesse'): 6,
#  ('Europe', 'Germany', 'Mecklenburg-Vorpommern'): 1,
#  ('Europe', 'Germany', 'North Rhine Westphalia'): 68,
#  ('Europe', 'Greece', 'Athens'): 101,
#  ('Europe', 'Hungary', 'Balassagyarmat'): 3,
#  ('Europe', 'Hungary', 'Balatonfured'): 1,
#  ('Europe', 'Hungary', 'Baranya'): 19,
#  ('Europe', 'Hungary', 'Bekesszentandras'): 1,
#  ('Europe', 'Hungary', 'Budapest'): 2,
#  ('Europe', 'Hungary', 'Kecskemet'): 3,
#  ('Europe', 'Hungary', 'Oroshaza'): 1,
#  ('Europe', 'Hungary', 'Szeged'): 2,
#  ('Europe', 'Iceland', 'Reykjavik'): 601,
#  ('Europe', 'Ireland', 'Cork'): 3,
#  ('Europe', 'Ireland', 'Dublin'): 4,
#  ('Europe', 'Ireland', 'Limerick'): 3,
#  ('Europe', 'Ireland', 'Louth'): 1,
#  ('Europe', 'Ireland', 'Tipperary'): 1,
#  ('Europe', 'Ireland', 'Wicklow'): 1,
#  ('Europe', 'Italy', 'Abruzzo'): 54,
#  ('Europe', 'Italy', 'Apulia'): 2,
#  ('Europe', 'Italy', 'Basilicata'): 1,
#  ('Europe', 'Italy', 'Emilia-Romagna'): 1,
#  ('Europe', 'Italy', 'Friuli Venezia Giulia'): 6,
#  ('Europe', 'Italy', 'Lazio'): 22,
#  ('Europe', 'Italy', 'Lombardia'): 4,
#  ('Europe', 'Italy', 'Lombardy'): 10,
#  ('Europe', 'Italy', 'Marche'): 1,
#  ('Europe', 'Italy', 'Molise'): 1,
#  ('Europe', 'Italy', 'PA Trento'): 1,
#  ('Europe', 'Italy', 'Sardinia'): 2,
#  ('Europe', 'Italy', 'Sicily'): 2,
#  ('Europe', 'Italy', "Valle D'Aosta"): 2,
#  ('Europe', 'Italy', 'Veneto'): 13,
#  ('Europe', 'Latvia', 'Riga'): 1,
#  ('Europe', 'Lithuania', 'Vilnius'): 1,
#  ('Europe', 'Netherlands', 'Drenthe'): 3,
#  ('Europe', 'Netherlands', 'Flevoland'): 5,
#  ('Europe', 'Netherlands', 'Friesland'): 16,
#  ('Europe', 'Netherlands', 'Gelderland'): 14,
#  ('Europe', 'Netherlands', 'Limburg'): 9,
#  ('Europe', 'Netherlands', 'North Brabant'): 112,
#  ('Europe', 'Netherlands', 'North Holland'): 7,
#  ('Europe', 'Netherlands', 'Overijssel'): 3,
#  ('Europe', 'Netherlands', 'South Holland'): 119,
#  ('Europe', 'Netherlands', 'Utrecht'): 76,
#  ('Europe', 'Norway', 'Oslo'): 8,
#  ('Europe', 'Norway', 'Trondheim'): 7,
#  ('Europe', 'Poland', 'Dolnoslaskie'): 2,
#  ('Europe', 'Poland', 'Lubusz'): 1,
#  ('Europe', 'Poland', 'Malopolskie'): 28,
#  ('Europe', 'Poland', 'Mazowieckie'): 8,
#  ('Europe', 'Poland', 'Pomorskie'): 24,
#  ('Europe', 'Poland', 'Slask'): 10,
#  ('Europe', 'Poland', 'Warminsko-Mazurskie'): 2,
#  ('Europe', 'Poland', 'Wielkopolskie'): 4,
#  ('Europe', 'Portugal', 'Lisbon'): 2,
#  ('Europe', 'Romania', 'Arges'): 3,
#  ('Europe', 'Romania', 'Bucuresti'): 7,
#  ('Europe', 'Romania', 'Buzau'): 1,
#  ('Europe', 'Romania', 'Constanta'): 2,
#  ('Europe', 'Russia', 'Buryat Republic'): 2,
#  ('Europe', 'Russia', 'Chechen Republic'): 2,
#  ('Europe', 'Russia', 'Chelyabinsk Region'): 1,
#  ('Europe', 'Russia', 'Khabarovsk Region'): 2,
#  ('Europe', 'Russia', 'Krasnodar Region'): 2,
#  ('Europe', 'Russia', 'Krasnoyarsk Region'): 1,
#  ('Europe', 'Russia', 'Leningrad region'): 1,
#  ('Europe', 'Russia', 'Lipetsk Region'): 2,
#  ('Europe', 'Russia', 'Moscow Region'): 33,
#  ('Europe', 'Russia', 'Novosibirsk Region'): 1,
#  ('Europe', 'Russia', 'Omsk Region'): 1,
#  ('Europe', 'Russia', 'Orenburg Region'): 1,
#  ('Europe', 'Russia', 'Perm Region'): 1,
#  ('Europe', 'Russia', 'Primorskiy Region'): 1,
#  ('Europe', 'Russia', 'Pskov Region'): 1,
#  ('Europe', 'Russia', 'Republic of Buryatia'): 8,
#  ('Europe', 'Russia', 'Republic of Crymea'): 1,
#  ('Europe', 'Russia', 'Republic of Kabardino-Balkaria'): 2,
#  ('Europe', 'Russia', 'Republic of Sakha (Yakutia)'): 5,
#  ('Europe', 'Russia', 'Saint Petersburg'): 136,
#  ('Europe', 'Russia', 'Sakhalin Region'): 1,
#  ('Europe', 'Russia', 'Samara Region'): 2,
#  ('Europe', 'Russia', 'Sverdlovsk Region'): 6,
#  ('Europe', 'Russia', 'Tatarstan'): 1,
#  ('Europe', 'Russia', 'Tver Region'): 1,
#  ('Europe', 'Serbia', 'Cacak'): 2,
#  ('Europe', 'Serbia', 'Kraljevo'): 3,
#  ('Europe', 'Serbia', 'Novi Pazar'): 1,
#  ('Europe', 'Slovakia', 'Bratislava'): 1,
#  ('Europe', 'Slovakia', 'Kosice'): 1,
#  ('Europe', 'Slovakia', 'Kostoliste'): 1,
#  ('Europe', 'Slovakia', 'Martin'): 1,
#  ('Europe', 'Spain', 'Andalusia'): 193,
#  ('Europe', 'Spain', 'Basque Country'): 182,
#  ('Europe', 'Spain', 'Canary Islands'): 3,
#  ('Europe', 'Spain', 'Castilla y León'): 4,
#  ('Europe', 'Spain', 'Castilla-La Mancha'): 3,
#  ('Europe', 'Spain', 'Catalonia'): 28,
#  ('Europe', 'Spain', 'Comunitat Valenciana'): 403,
#  ('Europe', 'Spain', 'Galicia'): 9,
#  ('Europe', 'Spain', 'La Rioja'): 12,
#  ('Europe', 'Spain', 'Madrid'): 78,
#  ('Europe', 'Spain', 'Melilla'): 6,
#  ('Europe', 'Spain', 'Navarra'): 63,
#  ('Europe', 'Sweden', 'Dalarna'): 3,
#  ('Europe', 'Sweden', 'Gavleborg'): 3,
#  ('Europe', 'Sweden', 'Halland'): 42,
#  ('Europe', 'Sweden', 'Jamtland'): 4,
#  ('Europe', 'Sweden', 'Jonkoping'): 4,
#  ('Europe', 'Sweden', 'Kalmar'): 3,
#  ('Europe', 'Sweden', 'Norrbotten'): 16,
#  ('Europe', 'Sweden', 'Orebro'): 7,
#  ('Europe', 'Sweden', 'Ostergotland'): 3,
#  ('Europe', 'Sweden', 'Skane'): 11,
#  ('Europe', 'Sweden', 'Sormland'): 8,
#  ('Europe', 'Sweden', 'Stockholm'): 154,
#  ('Europe', 'Sweden', 'Uppsala'): 25,
#  ('Europe', 'Sweden', 'Varmland'): 22,
#  ('Europe', 'Sweden', 'Vasternorrland'): 6,
#  ('Europe', 'Sweden', 'Vastmanland'): 5,
#  ('Europe', 'Sweden', 'Vastra Gotaland'): 33,
#  ('Europe', 'Sweden', 'Västerbotten'): 4,
#  ('Europe', 'Switzerland', 'Aargau'): 18,
#  ('Europe', 'Switzerland', 'Basel-Stadt'): 84,
#  ('Europe', 'Switzerland', 'Bern'): 34,
#  ('Europe', 'Switzerland', 'Fribourg'): 1,
#  ('Europe', 'Switzerland', 'Geneva'): 8,
#  ('Europe', 'Switzerland', 'Glarus'): 2,
#  ('Europe', 'Switzerland', 'Graubunden'): 24,
#  ('Europe', 'Switzerland', 'Jura'): 4,
#  ('Europe', 'Switzerland', 'Lucerne'): 6,
#  ('Europe', 'Switzerland', 'Sankt Gallen'): 3,
#  ('Europe', 'Switzerland', 'Schaffhausen'): 2,
#  ('Europe', 'Switzerland', 'Schwyz'): 6,
#  ('Europe', 'Switzerland', 'Tessin'): 1,
#  ('Europe', 'Switzerland', 'Thurgau'): 1,
#  ('Europe', 'Switzerland', 'Ticino'): 13,
#  ('Europe', 'Switzerland', 'Uri'): 3,
#  ('Europe', 'Switzerland', 'Valais'): 8,
#  ('Europe', 'Switzerland', 'Vaud'): 26,
#  ('Europe', 'Switzerland', 'Zurich'): 41,
#  ('Europe', 'Turkey', 'Adıyaman'): 1,
#  ('Europe', 'Turkey', 'Afyon'): 1,
#  ('Europe', 'Turkey', 'Agri'): 1,
#  ('Europe', 'Turkey', 'Aksaray'): 1,
#  ('Europe', 'Turkey', 'Ankara'): 20,
#  ('Europe', 'Turkey', 'Balikesir'): 2,
#  ('Europe', 'Turkey', 'Canakkale'): 1,
#  ('Europe', 'Turkey', 'Denizli'): 2,
#  ('Europe', 'Turkey', 'Eskisehir'): 1,
#  ('Europe', 'Turkey', 'Istanbul'): 11,
#  ('Europe', 'Turkey', 'Karaman'): 1,
#  ('Europe', 'Turkey', 'Kastamonu'): 1,
#  ('Europe', 'Turkey', 'Kayseri'): 1,
#  ('Europe', 'Turkey', 'Kocaeli'): 9,
#  ('Europe', 'Turkey', 'Konya'): 1,
#  ('Europe', 'Turkey', 'Mardin'): 1,
#  ('Europe', 'Turkey', 'Nevsehir'): 2,
#  ('Europe', 'Turkey', 'Sakarya'): 3,
#  ('Europe', 'Turkey', 'Siirt'): 1,
#  ('Europe', 'Turkey', 'Tekirdag'): 1,
#  ('Europe', 'Turkey', 'Tokat'): 1,
#  ('Europe', 'United Kingdom', 'England'): 11609,
#  ('Europe', 'United Kingdom', 'Northern Ireland'): 200,
#  ('Europe', 'United Kingdom', 'Scotland'): 2311,
#  ('Europe', 'United Kingdom', 'Wales'): 2845,
#  ('Europe', '\u200eRomania', 'Bucharest'): 1,
#  ('North America', 'Canada', 'British Columbia'): 58,
#  ('North America', 'Canada', 'Manitoba'): 7,
#  ('North America', 'Canada', 'New Brunswick'): 4,
#  ('North America', 'Canada', 'Newfoundland and Labrador'): 1,
#  ('North America', 'Canada', 'Nova Scotia'): 4,
#  ('North America', 'Canada', 'Ontario'): 67,
#  ('North America', 'Canada', 'Quebec'): 61,
#  ('North America', 'Canada', 'Saskatchewan'): 5,
#  ('North America', 'Mexico', 'Chiapas'): 1,
#  ('North America', 'Mexico', 'Chihuahua'): 1,
#  ('North America', 'Mexico', 'Durango'): 1,
#  ('North America', 'Mexico', 'Estado de Mexico'): 1,
#  ('North America', 'Mexico', 'Guerrero'): 1,
#  ('North America', 'Mexico', 'Jalisco'): 2,
#  ('North America', 'Mexico', 'Mexico City'): 15,
#  ('North America', 'Mexico', 'Puebla'): 2,
#  ('North America', 'Mexico', 'Queretaro'): 2,
#  ('North America', 'Mexico', 'Quintana Roo'): 1,
#  ('North America', 'Panama', 'Panama City'): 1,
#  ('North America', 'USA', 'Alabama'): 1,
#  ('North America', 'USA', 'Alaska'): 31,
#  ('North America', 'USA', 'Arizona'): 85,
#  ('North America', 'USA', 'Arkansas'): 1,
#  ('North America', 'USA', 'California'): 586,
#  ('North America', 'USA', 'Colorado'): 5,
#  ('North America', 'USA', 'Connecticut'): 192,
#  ('North America', 'USA', 'Florida'): 156,
#  ('North America', 'USA', 'Georgia'): 26,
#  ('North America', 'USA', 'Hawaii'): 2,
#  ('North America', 'USA', 'Idaho'): 53,
#  ('North America', 'USA', 'Illinois'): 132,
#  ('North America', 'USA', 'Indiana'): 13,
#  ('North America', 'USA', 'Iowa'): 28,
#  ('North America', 'USA', 'Kansas'): 2,
#  ('North America', 'USA', 'Los Angeles'): 15,
#  ('North America', 'USA', 'Louisiana'): 299,
#  ('North America', 'USA', 'Maryland'): 101,
#  ('North America', 'USA', 'Massachusetts'): 18,
#  ('North America', 'USA', 'Michigan'): 449,
#  ('North America', 'USA', 'Minnesota'): 153,
#  ('North America', 'USA', 'Missouri'): 1,
#  ('North America', 'USA', 'Montana'): 2,
#  ('North America', 'USA', 'Nebraska'): 7,
#  ('North America', 'USA', 'Nevada'): 2,
#  ('North America', 'USA', 'New Hampshire'): 4,
#  ('North America', 'USA', 'New Jersey'): 32,
#  ('North America', 'USA', 'New Mexico'): 1,
#  ('North America', 'USA', 'New York'): 1392,
#  ('North America', 'USA', 'North Carolina'): 48,
#  ('North America', 'USA', 'Ohio'): 11,
#  ('North America', 'USA', 'Oregon'): 28,
#  ('North America', 'USA', 'Pennsylvania'): 110,
#  ('North America', 'USA', 'Puerto Rico'): 14,
#  ('North America', 'USA', 'Rhode Island'): 4,
#  ('North America', 'USA', 'South Carolina'): 10,
#  ('North America', 'USA', 'Texas'): 336,
#  ('North America', 'USA', 'Utah'): 302,
#  ('North America', 'USA', 'Vermont'): 1,
#  ('North America', 'USA', 'Virgin Islands'): 17,
#  ('North America', 'USA', 'Virginia'): 247,
#  ('North America', 'USA', 'Washington'): 1751,
#  ('North America', 'USA', 'Washington DC'): 38,
#  ('North America', 'USA', 'Wisconsin'): 372,
#  ('North America', 'USA', 'Wyoming'): 16,
#  ('Oceania', 'Australia', 'New South Wales'): 438,
#  ('Oceania', 'Australia', 'Northern Territory'): 27,
#  ('Oceania', 'Australia', 'Queensland'): 21,
#  ('Oceania', 'Australia', 'South Australia'): 84,
#  ('Oceania', 'Australia', 'Victoria'): 1309,
#  ('Oceania', 'Australia', 'Western Australia'): 8,
#  ('Oceania', 'New Zealand', 'Auckland'): 55,
#  ('Oceania', 'New Zealand', 'Bay of Plenty'): 8,
#  ('Oceania', 'New Zealand', 'Canterbury'): 32,
#  ('Oceania', 'New Zealand', 'Lakes'): 1,
#  ('Oceania', 'New Zealand', 'MidCentral'): 2,
#  ('Oceania', 'New Zealand', 'Nelson Marlborough'): 1,
#  ('Oceania', 'New Zealand', 'Otago'): 2,
#  ('Oceania', 'New Zealand', 'Southern'): 95,
#  ('Oceania', 'New Zealand', 'Waikato'): 12,
#  ('Oceania', 'New Zealand', 'Wairarapa'): 4,
#  ('Oceania', 'New Zealand', 'Waitemata'): 5,
#  ('Oceania', 'New Zealand', 'Wellington'): 38,
#  ('South America', 'Argentina', 'Buenos Aires'): 25,
#  ('South America', 'Argentina', 'Rio Negro'): 1,
#  ('South America', 'Brazil', 'Alagoas'): 1,
#  ('South America', 'Brazil', 'Amapa'): 1,
#  ('South America', 'Brazil', 'Amazonas State'): 1,
#  ('South America', 'Brazil', 'Bahia'): 2,
#  ('South America', 'Brazil', 'Distrito Federal'): 7,
#  ('South America', 'Brazil', 'Espirito Santo'): 1,
#  ('South America', 'Brazil', 'Goiais'): 1,
#  ('South America', 'Brazil', 'Minas Gerais'): 45,
#  ('South America', 'Brazil', 'Para'): 1,
#  ('South America', 'Brazil', 'Rio Grande do Sul'): 1,
#  ('South America', 'Brazil', 'Rio de Janeiro'): 50,
#  ('South America', 'Brazil', 'Santa Catarina'): 2,
#  ('South America', 'Brazil', 'Sao Paulo'): 16,
#  ('South America', 'Chile', 'Antofagasta'): 2,
#  ('South America', 'Chile', 'Chillan'): 4,
#  ('South America', 'Chile', 'Concepcion'): 3,
#  ('South America', 'Chile', 'Coyhaique'): 1,
#  ('South America', 'Chile', 'Puerto Montt'): 3,
#  ('South America', 'Chile', 'Punta Arenas'): 17,
#  ('South America', 'Chile', 'Rancagua'): 9,
#  ('South America', 'Chile', 'Santiago'): 84,
#  ('South America', 'Chile', 'Talca'): 2,
#  ('South America', 'Chile', 'Temuco'): 14,
#  ('South America', 'Chile', 'Valparaiso'): 5,
#  ('South America', 'Colombia', 'Amazonas'): 1,
#  ('South America', 'Colombia', 'Antioquia'): 13,
#  ('South America', 'Colombia', 'Atlantico'): 1,
#  ('South America', 'Colombia', 'Bogota'): 3,
#  ('South America', 'Colombia', 'Bolivar'): 3,
#  ('South America', 'Colombia', 'Boyaca'): 9,
#  ('South America', 'Colombia', 'Caldas'): 3,
#  ('South America', 'Colombia', 'Cauca'): 1,
#  ('South America', 'Colombia', 'Cesar'): 1,
#  ('South America', 'Colombia', 'Choco'): 1,
#  ('South America', 'Colombia', 'Cordoba'): 2,
#  ('South America', 'Colombia', 'Cundinamarca'): 9,
#  ('South America', 'Colombia', 'Huila'): 7,
#  ('South America', 'Colombia', 'Magdalena'): 4,
#  ('South America', 'Colombia', 'Meta'): 3,
#  ('South America', 'Colombia', 'Narino'): 4,
#  ('South America', 'Colombia', 'Norte de Santander'): 3,
#  ('South America', 'Colombia', 'Quindio'): 2,
#  ('South America', 'Colombia', 'Risaralda'): 5,
#  ('South America', 'Colombia', 'Santander'): 3,
#  ('South America', 'Colombia', 'Tolima'): 3,
#  ('South America', 'Colombia', 'Valle del Cauca'): 47,
#  ('South America', 'Ecuador', 'Pichincha'): 3,
#  ('South America', 'Ecuador', 'Quito'): 1,
#  ('South America', 'Peru', 'Lima'): 2,
#  ('South America', 'Uruguay', 'Montevideo'): 45}

# %%
# Count sequences by region, country, division, and location
dict(df.groupby(['region', 'country', 'division', 'location'])['gisaid_id'].count())
# Out:
# {('Asia', 'Bangladesh', 'Chuandanga', 'Sadar'): 1,
#  ('Asia', 'Bangladesh', 'Jhenaidha', 'Shailokupa'): 1,
#  ('Asia', 'China', 'Anhui', 'Fuyang'): 1,
#  ('Asia', 'China', 'Anhui', 'Suzhou'): 1,
#  ('Asia', 'China', 'Guangdong', 'Dongguan'): 4,
#  ('Asia', 'China', 'Guangdong', 'Foshan'): 7,
#  ('Asia', 'China', 'Guangdong', 'Guangzhou'): 61,
#  ('Asia', 'China', 'Guangdong', 'Huizhou'): 10,
#  ('Asia', 'China', 'Guangdong', 'Meizhou'): 2,
#  ('Asia', 'China', 'Guangdong', 'Shantou'): 2,
#  ('Asia', 'China', 'Guangdong', 'Shanwei'): 1,
#  ('Asia', 'China', 'Guangdong', 'Shaoguan'): 1,
#  ('Asia', 'China', 'Guangdong', 'Shenzhen'): 25,
#  ('Asia', 'China', 'Guangdong', 'Yangjiang'): 1,
#  ('Asia', 'China', 'Guangdong', 'Zhanjiang'): 2,
#  ('Asia', 'China', 'Guangdong', 'Zhongshan'): 1,
#  ('Asia', 'China', 'Guangdong', 'Zhuhai'): 11,
#  ('Asia', 'China', 'Hubei', 'Tianmen'): 1,
#  ('Asia', 'China', 'Hubei', 'Wuhan'): 219,
#  ('Asia', 'China', 'Jiangsu', 'Changzhou'): 1,
#  ('Asia', 'China', 'Jiangxi', 'Fuzhou'): 3,
#  ('Asia', 'China', 'Jiangxi', 'Ganzhou'): 1,
#  ('Asia', 'China', 'Jiangxi', 'Jian'): 2,
#  ('Asia', 'China', 'Jiangxi', 'Jiujiang'): 2,
#  ('Asia', 'China', 'Jiangxi', 'Nanchang'): 10,
#  ('Asia', 'China', 'Jiangxi', 'Pingxiang'): 2,
#  ('Asia', 'China', 'Jiangxi', 'Shangrao'): 8,
#  ('Asia', 'China', 'Jiangxi', 'Xinyu'): 2,
#  ('Asia', 'China', 'Jiangxi', 'Yichun'): 3,
#  ('Asia', 'China', 'Jiangxi', 'Yingtan'): 1,
#  ('Asia', 'China', 'Yunnan', "Pu'er"): 2,
#  ('Asia', 'China', 'Yunnan', 'Xishuangbanna'): 2,
#  ('Asia', 'China', 'Zhejiang', 'Hangzhou'): 42,
#  ('Asia', 'China', 'Zhejiang', 'Lishui'): 4,
#  ('Asia', 'India', 'Gujarat', 'Ahmedabad'): 60,
#  ('Asia', 'India', 'Gujarat', 'Botad'): 1,
#  ('Asia', 'India', 'Gujarat', 'Dahegam'): 3,
#  ('Asia', 'India', 'Gujarat', 'Dahod'): 4,
#  ('Asia', 'India', 'Gujarat', 'Dhansura'): 1,
#  ('Asia', 'India', 'Gujarat', 'Gandhinagar'): 13,
#  ('Asia', 'India', 'Gujarat', 'Himatnagar'): 1,
#  ('Asia', 'India', 'Gujarat', 'Jamnagar'): 6,
#  ('Asia', 'India', 'Gujarat', 'Junagadh'): 1,
#  ('Asia', 'India', 'Gujarat', 'Kodinar'): 1,
#  ('Asia', 'India', 'Gujarat', 'Mansa'): 2,
#  ('Asia', 'India', 'Gujarat', 'Modasa'): 13,
#  ('Asia', 'India', 'Gujarat', 'Prantij'): 3,
#  ('Asia', 'India', 'Gujarat', 'Rajkot'): 5,
#  ('Asia', 'India', 'Gujarat', 'Surat'): 7,
#  ('Asia', 'India', 'Gujarat', 'Una'): 3,
#  ('Asia', 'India', 'Gujarat', 'Vadodara'): 17,
#  ('Asia', 'India', 'Jammu and Kashmir', 'Jammu'): 1,
#  ('Asia', 'India', 'Ladakh', 'Kargil'): 1,
#  ('Asia', 'India', 'Maharashtra', 'Mumbai'): 2,
#  ('Asia', 'India', 'Rajasthan', 'Bikaner'): 1,
#  ('Asia', 'India', 'Rajasthan', 'Jaipur'): 4,
#  ('Asia', 'India', 'Telangana', 'Hyderabad'): 7,
#  ('Asia', 'India', 'Uttar Pradesh', 'Noida'): 1,
#  ('Asia', 'India', 'West Bengal', 'Darjeeling'): 1,
#  ('Asia', 'India', 'West Bengal', 'East Medinipur'): 6,
#  ('Asia', 'India', 'West Bengal', 'Howrah'): 3,
#  ('Asia', 'India', 'West Bengal', 'Kolkata'): 21,
#  ('Asia', 'India', 'West Bengal', 'North 24 Parganas'): 6,
#  ('Asia', 'India', 'West Bengal', 'South 24 Parganas'): 10,
#  ('Asia', 'India', 'West Bengal', 'Tehatta'): 1,
#  ('Asia', 'Indonesia', 'West Java', 'Indramayu'): 1,
#  ('Asia', 'Iran', 'Tehran', 'Nazi Abad'): 1,
#  ('Europe', 'Belgium', 'Antwerp', 'Antwerp'): 36,
#  ('Europe', 'Belgium', 'Antwerp', 'Bonheiden'): 1,
#  ('Europe', 'Belgium', 'Antwerp', 'Hemiksem'): 1,
#  ('Europe', 'Belgium', 'Antwerp', 'Herselt'): 1,
#  ('Europe', 'Belgium', 'Antwerp', 'Kalmthout'): 2,
#  ('Europe', 'Belgium', 'Antwerp', 'Kasterlee'): 1,
#  ('Europe', 'Belgium', 'Antwerp', 'Lille'): 1,
#  ('Europe', 'Belgium', 'Antwerp', 'Ravels'): 1,
#  ('Europe', 'Belgium', 'Antwerp', 'Schoten'): 1,
#  ('Europe', 'Belgium', 'Antwerp', 'Westerlo'): 1,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Anderlecht'): 1,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Auderghem'): 2,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Brussels'): 10,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Etterbeek'): 1,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Forest'): 3,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Ganshoren'): 1,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Ixelles'): 1,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Sint-Agatha-Berchem'): 2,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Uccle'): 2,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Watermael-Boitsfort'): 3,
#  ('Europe', 'Belgium', 'Brussels-Capital Region', 'Woluwe-Saint-Pierre'): 2,
#  ('Europe', 'Belgium', 'East Flanders', 'Deinze'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Dendermonde'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Geraardsbergen'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Ghent'): 59,
#  ('Europe', 'Belgium', 'East Flanders', 'Merelbeke'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Nevele'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Ronse'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Sint-Gillis-Waas'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Sint-Niklaas'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Stekene'): 1,
#  ('Europe', 'Belgium', 'East Flanders', 'Waasmunster'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Asse'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Beersel'): 2,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Bierbeek'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Boutersem'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Dilbeek'): 2,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Grimbergen'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Herent'): 2,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Hoegaarden'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Holsbeek'): 4,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Huldenberg'): 4,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Kraainem'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Leuven'): 9,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Linter'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Lubbeek'): 2,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Sint-Genesius-Rode'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Tervuren'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Tielt-Winge'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Tienen'): 1,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Vilvoorde'): 2,
#  ('Europe', 'Belgium', 'Flemish Brabant', 'Zoutleeuw'): 2,
#  ('Europe', 'Belgium', 'Hainaut', 'Ath'): 2,
#  ('Europe', 'Belgium', 'Hainaut', 'Belœil'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Boussu'): 2,
#  ('Europe', 'Belgium', 'Hainaut', 'Charleroi'): 4,
#  ('Europe', 'Belgium', 'Hainaut', 'Colfontaine'): 3,
#  ('Europe', 'Belgium', 'Hainaut', 'Comines-Warneton'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Cuesmes'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Ellezelles'): 1,
#  ('Europe', 'Belgium', 'Hainaut', "Fontaine-l'Évêque"): 2,
#  ('Europe', 'Belgium', 'Hainaut', 'Frameries'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Haulchin'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Honnelles'): 2,
#  ('Europe', 'Belgium', 'Hainaut', 'La Louvière'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Mons'): 8,
#  ('Europe', 'Belgium', 'Hainaut', 'Montigny-le-Tilleul'): 2,
#  ('Europe', 'Belgium', 'Hainaut', 'Mouscron'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Quaregnon'): 3,
#  ('Europe', 'Belgium', 'Hainaut', 'Quevy'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Saint-Ghislain'): 3,
#  ('Europe', 'Belgium', 'Hainaut', 'Silly'): 1,
#  ('Europe', 'Belgium', 'Hainaut', 'Soignies'): 3,
#  ('Europe', 'Belgium', 'Hainaut', 'Tournai'): 3,
#  ('Europe', 'Belgium', 'Liege', 'Blegny'): 1,
#  ('Europe', 'Belgium', 'Liege', 'Limbourg'): 1,
#  ('Europe', 'Belgium', 'Liege', 'Liège'): 263,
#  ('Europe', 'Belgium', 'Liege', 'Nandrin'): 1,
#  ('Europe', 'Belgium', 'Liege', 'Seraing'): 1,
#  ('Europe', 'Belgium', 'Liege', 'Soumagne'): 1,
#  ('Europe', 'Belgium', 'Liege', 'Theux'): 1,
#  ('Europe', 'Belgium', 'Liege', 'Wandre'): 1,
#  ('Europe', 'Belgium', 'Liege', 'Wanze'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Alken'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Beringen'): 2,
#  ('Europe', 'Belgium', 'Limburg', 'Bree'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Hasselt'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Heusden-Zolder'): 2,
#  ('Europe', 'Belgium', 'Limburg', 'Houthalen-Helchteren'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Kaulille'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Lanaken'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Lummen'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Nieuwerkerken'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Pelt'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Riemst'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Sint-Truiden'): 1,
#  ('Europe', 'Belgium', 'Limburg', 'Zonhoven'): 2,
#  ('Europe', 'Belgium', 'Namur', 'Andenne'): 1,
#  ('Europe', 'Belgium', 'Namur', 'Couvin'): 1,
#  ('Europe', 'Belgium', 'Namur', 'Havelange'): 1,
#  ('Europe', 'Belgium', 'Namur', 'Namur'): 1,
#  ('Europe', 'Belgium', 'Walloon Brabant', "Braine-l'Alleud"): 1,
#  ('Europe', 'Belgium', 'Walloon Brabant', 'Braine-le-Château'): 1,
#  ('Europe', 'Belgium', 'Walloon Brabant', 'Genappe'): 1,
#  ('Europe', 'Belgium', 'Walloon Brabant', 'Lasne'): 2,
#  ('Europe', 'Belgium', 'Walloon Brabant', 'Rixensart'): 2,
#  ('Europe', 'Belgium', 'Walloon Brabant', 'Tubize'): 1,
#  ('Europe', 'Belgium', 'Walloon Brabant', 'Waterloo'): 2,
#  ('Europe', 'Belgium', 'West Flanders', 'Knokke-Heist'): 1,
#  ('Europe', 'Belgium', 'West Flanders', 'Oostrozebeke'): 1,
#  ('Europe', 'Belgium', 'West Flanders', 'Wervik'): 1,
#  ('Europe', 'Belgium', 'West Flanders', 'Wevelgem'): 1,
#  ('Europe', 'Czechia', 'Vysocina Region', 'Bela - Ledec na Sazavou'): 1,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes', 'Bourg-en-Bresse'): 5,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes', 'Lyon'): 42,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes', 'Macon'): 9,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes', 'Privas'): 1,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes', 'Saint-Priest'): 1,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes', 'Valence'): 4,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes', 'Venissieux'): 1,
#  ('Europe', 'France', 'Auvergne-Rhône-Alpes', 'Vienne'): 1,
#  ('Europe', 'France', 'Bourgogne-Franche-Comté', 'Chalon sur Saone'): 1,
#  ('Europe', 'France', 'Bourgogne-Franche-Comté', 'Dijon'): 4,
#  ('Europe', 'France', 'Bourgogne-Franche-Comté', 'Montreux-Chateau'): 2,
#  ('Europe', 'France', 'Bourgogne-Franche-Comté', 'Thise'): 1,
#  ('Europe', 'France', 'Bretagne', 'Brest'): 20,
#  ('Europe', 'France', 'Bretagne', 'Ploudalmezeau'): 1,
#  ('Europe', 'France', 'Bretagne', 'Rennes'): 18,
#  ('Europe', 'France', 'Centre-Val de Loire', 'Abondant'): 2,
#  ('Europe', 'France', 'Centre-Val de Loire', 'Tours'): 1,
#  ('Europe', 'France', 'Grand Est', 'Gondrecourt-le-chateau'): 1,
#  ('Europe', 'France', 'Grand Est', 'Ham sous Varsberg'): 1,
#  ('Europe', 'France', 'Grand Est', 'Nancy'): 1,
#  ('Europe', 'France', 'Grand Est', 'Reims'): 2,
#  ('Europe', 'France', 'Grand Est', 'Spicheren'): 1,
#  ('Europe', 'France', 'Grand Est', 'Strasbourg'): 4,
#  ('Europe', 'France', 'Grand Est', 'Woippy'): 1,
#  ('Europe', 'France', 'Hauts-de-France', 'Chateau-Thierry'): 2,
#  ('Europe', 'France', 'Hauts-de-France', 'Chateau-thierry'): 3,
#  ('Europe', 'France', 'Hauts-de-France', 'Château-Thierry'): 1,
#  ('Europe', 'France', 'Hauts-de-France', 'Compiegne'): 15,
#  ('Europe', 'France', 'Hauts-de-France', 'Compiègne'): 27,
#  ('Europe', 'France', 'Hauts-de-France', 'Crouy en Thelle'): 1,
#  ('Europe', 'France', 'Hauts-de-France', 'Crépy en Valois'): 1,
#  ('Europe', 'France', 'Hauts-de-France', 'Crépy-en -Valois'): 1,
#  ('Europe', 'France', 'Hauts-de-France', "Nogent l'Artaud"): 1,
#  ('Europe', 'France', 'Hauts-de-France', 'Pontoise'): 5,
#  ('Europe', 'France', 'Normandie', 'Carentan'): 1,
#  ('Europe', 'France', 'Normandie', 'Rouen'): 2,
#  ('Europe', 'France', 'Occitanie', 'Toulouse'): 1,
#  ('Europe', 'France', 'Pays de la Loire', 'Nantes'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Asnieres sur Seine'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Asnières-sur-Seine'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Cergy'): 2,
#  ('Europe', 'France', 'Île-de-France', 'Colombes'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Garches'): 4,
#  ('Europe', 'France', 'Île-de-France', 'Gennevilliers'): 2,
#  ('Europe', 'France', 'Île-de-France', 'Guyancourt'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Juvisy-sur-Orge'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Levallois-Perret'): 2,
#  ('Europe', 'France', 'Île-de-France', 'Longjumeau'): 24,
#  ('Europe', 'France', 'Île-de-France', 'Meudon la Forêt'): 2,
#  ('Europe', 'France', 'Île-de-France', 'Montigny le Bretonneux'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Moussy Le Neuf'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Moussy le Neuf'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Noisy le Roi'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Orsay'): 5,
#  ('Europe', 'France', 'Île-de-France', 'Paris'): 14,
#  ('Europe', 'France', 'Île-de-France', 'Pecq'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Pontoise'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Saint Germain en Laye'): 2,
#  ('Europe', 'France', 'Île-de-France', 'Saint-Thibault-des-Vignes'): 1,
#  ('Europe', 'France', 'Île-de-France', 'Seine-Port'): 2,
#  ('Europe', 'France', 'Île-de-France', 'Vanves'): 1,
#  ('Europe', 'Germany', 'Bavaria', 'Munich'): 127,
#  ('Europe', 'Germany', 'Hesse', 'Frankfurt'): 6,
#  ('Europe', 'Germany', 'Mecklenburg-Vorpommern', 'Rostock'): 1,
#  ('Europe', 'Germany', 'North Rhine Westphalia', 'Duesseldorf'): 58,
#  ('Europe', 'Germany', 'North Rhine Westphalia', 'Heinsberg District'): 10,
#  ('Europe', 'Italy', 'Abruzzo', 'Castel di Sangro'): 1,
#  ('Europe', 'Italy', 'Abruzzo', "L'Aquila"): 1,
#  ('Europe', 'Italy', 'Abruzzo', 'Teramo'): 2,
#  ('Europe', 'Italy', 'Lazio', 'Rome'): 14,
#  ('Europe', 'Italy', 'Lombardy', 'Milan'): 7,
#  ('Europe', 'Italy', 'Sardinia', 'Cagliari'): 1,
#  ('Europe', 'Italy', 'Sicily', 'Palermo'): 1,
#  ('Europe', 'Italy', 'Veneto', 'Verona'): 13,
#  ('Europe', 'Netherlands', 'Drenthe', 'Coevorden'): 2,
#  ('Europe', 'Netherlands', 'Flevoland', 'Zeewolde'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Altena'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Eindhoven'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Helmond'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Loop op Zand'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Milheeze'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Oisterwijk'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Oss'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Sint-Michielsgestel'): 1,
#  ('Europe', 'Netherlands', 'North Brabant', 'Tilburg'): 3,
#  ('Europe', 'Netherlands', 'North Holland', 'Blaricum'): 1,
#  ('Europe', 'Netherlands', 'North Holland', 'Diemen'): 1,
#  ('Europe', 'Netherlands', 'North Holland', 'Gooise Meren'): 1,
#  ('Europe', 'Netherlands', 'North Holland', 'Haarlem'): 1,
#  ('Europe', 'Netherlands', 'South Holland', 'Delft'): 1,
#  ('Europe', 'Netherlands', 'South Holland', 'Hardinxveld-Giessendam'): 1,
#  ('Europe', 'Netherlands', 'South Holland', 'Leiden'): 1,
#  ('Europe', 'Netherlands', 'South Holland', 'Nieuwendijk'): 1,
#  ('Europe', 'Netherlands', 'South Holland', 'Nootdorp'): 1,
#  ('Europe', 'Netherlands', 'South Holland', 'Rotterdam'): 3,
#  ('Europe', 'Netherlands', 'Utrecht', 'Houten'): 1,
#  ('Europe', 'Poland', 'Malopolskie', 'Krakow'): 3,
#  ('Europe', 'Poland', 'Malopolskie', 'Kraków'): 16,
#  ('Europe', 'Poland', 'Mazowieckie', 'Grodzisk Mazowiecki'): 1,
#  ('Europe', 'Poland', 'Mazowieckie', 'Plock'): 2,
#  ('Europe', 'Poland', 'Mazowieckie', 'Radom'): 1,
#  ('Europe', 'Poland', 'Mazowieckie', 'Warszawa'): 4,
#  ('Europe', 'Poland', 'Warminsko-Mazurskie', 'Olsztyn'): 2,
#  ('Europe', 'Poland', 'Wielkopolskie', 'Kalisz'): 1,
#  ('Europe', 'Russia', 'Buryat Republic', 'Ulan-Ude'): 2,
#  ('Europe', 'Russia', 'Leningrad region', 'Kipen'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Algeciras'): 3,
#  ('Europe', 'Spain', 'Andalusia', 'Alhaurin_de_la_Torre'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Almeria'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Antequera'): 2,
#  ('Europe', 'Spain', 'Andalusia', 'Benajarafe'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Cadiz'): 4,
#  ('Europe', 'Spain', 'Andalusia', 'Chiclana'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Conil'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Jerez_de_la_Frontera'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'La_Linea'): 2,
#  ('Europe', 'Spain', 'Andalusia', 'Mairena_Aljarafe'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Malaga'): 71,
#  ('Europe', 'Spain', 'Andalusia', 'Puerto_Santa_Maria'): 3,
#  ('Europe', 'Spain', 'Andalusia', 'Rincon_de_la_Victoria'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Rota'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'San_Fernando'): 2,
#  ('Europe', 'Spain', 'Andalusia', 'San_Roque'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Sevilla'): 74,
#  ('Europe', 'Spain', 'Andalusia', 'Torremolinos'): 1,
#  ('Europe', 'Spain', 'Andalusia', 'Velez_Malaga'): 7,
#  ('Europe', 'Spain', 'Basque Country', 'Bermeo'): 1,
#  ('Europe', 'Spain', 'Basque Country', 'Donostia-San_Sebastian'): 75,
#  ('Europe', 'Spain', 'Basque Country', 'Portugalete'): 1,
#  ('Europe', 'Spain', 'Basque Country', 'Vitoria'): 95,
#  ('Europe', 'Spain', 'Basque Country', 'Vitoria_h'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Albal'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Alboraya'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Albuixech'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Almassera'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Almenara'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Beniganim'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Benirredra'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Bonrepos i Mirambell'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', "Canet d'En Berenguer"): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Chilches'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'El Puig'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Elda'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Gandia'): 12,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Gilet'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Grau de Sagunt'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Lutxent'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Meliana'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Miramar'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Museros'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Oliva'): 4,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Olleria'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Palma de Gandia'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Puzol'): 2,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Sagunt'): 5,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Segorbe'): 2,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Simat_de_la_Valldigna'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Soneja'): 1,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Tavernes de la Valldigna'): 8,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Valencia'): 347,
#  ('Europe', 'Spain', 'Comunitat Valenciana', 'Xeraco'): 1,
#  ('Europe', 'Spain', 'La Rioja', 'Calahorra'): 1,
#  ('Europe', 'Spain', 'La Rioja', 'Logrono'): 1,
#  ('Europe', 'Spain', 'La Rioja', 'Pradejon'): 1,
#  ('Europe', 'Spain', 'Madrid', 'Alcobendas'): 1,
#  ('Europe', 'Spain', 'Madrid', 'Madrid'): 2,
#  ('Europe', 'Spain', 'Navarra', 'Baranain'): 3,
#  ('Europe', 'Spain', 'Navarra', 'Barasoain'): 2,
#  ('Europe', 'Spain', 'Navarra', 'Cintruenigo'): 1,
#  ('Europe', 'Spain', 'Navarra', 'Cizur'): 10,
#  ('Europe', 'Spain', 'Navarra', 'Echavarri'): 1,
#  ('Europe', 'Spain', 'Navarra', 'Fitero'): 1,
#  ('Europe', 'Spain', 'Navarra', 'Mutilva'): 2,
#  ('Europe', 'Spain', 'Navarra', 'Noain'): 1,
#  ('Europe', 'Spain', 'Navarra', 'Pamplona'): 37,
#  ('Europe', 'Spain', 'Navarra', 'Peralta'): 1,
#  ('Europe', 'Spain', 'Navarra', 'Tafalla'): 2,
#  ('Europe', 'Spain', 'Navarra', 'Torres_de_Elorz'): 1,
#  ('Europe', 'Spain', 'Navarra', 'Zulueta'): 1,
#  ('Europe', 'United Kingdom', 'England', 'Derbyshire'): 11,
#  ('Europe', 'United Kingdom', 'England', 'London'): 2,
#  ('Europe', 'United Kingdom', 'England', 'Northamptonshire'): 1,
#  ('Europe', 'United Kingdom', 'England', 'Nottinghamhisre'): 1,
#  ('Europe', 'United Kingdom', 'England', 'South Yorkshire'): 171,
#  ('Europe', 'United Kingdom', 'England', 'Yorkshire'): 2,
#  ('Europe', 'United Kingdom', 'Wales', 'Cardiff'): 1,
#  ('North America', 'USA', 'Alaska', 'Anchorage'): 10,
#  ('North America', 'USA', 'Alaska', 'Interior'): 12,
#  ('North America', 'USA', 'Alaska', 'Mat-Su'): 3,
#  ('North America', 'USA', 'Alaska', 'Southeast'): 6,
#  ('North America', 'USA', 'Arizona', 'Phoenix'): 2,
#  ('North America', 'USA', 'California', 'Alameda County'): 7,
#  ('North America', 'USA', 'California', 'Grand Princess Cruise Ship'): 9,
#  ('North America', 'USA', 'California', 'Humboldt County'): 6,
#  ('North America', 'USA', 'California', 'Los Angeles'): 2,
#  ('North America', 'USA', 'California', 'Marin County'): 2,
#  ('North America', 'USA', 'California', 'Orange County'): 2,
#  ('North America', 'USA', 'California', 'Sacramento County'): 1,
#  ('North America', 'USA', 'California', 'San Diego County'): 92,
#  ('North America', 'USA', 'California', 'San Francisco County'): 171,
#  ('North America', 'USA', 'California', 'San Joaquin County'): 1,
#  ('North America', 'USA', 'California', 'San Luis Obispo County'): 1,
#  ('North America', 'USA', 'California', 'San Mateo County'): 3,
#  ('North America', 'USA', 'California', 'Santa Clara County'): 268,
#  ('North America', 'USA', 'California', 'Solano County'): 5,
#  ('North America', 'USA', 'California', 'Sonoma County'): 1,
#  ('North America', 'USA', 'California', 'Yolo County'): 10,
#  ('North America', 'USA', 'Colorado', 'Colorado Springs'): 1,
#  ('North America', 'USA', 'Connecticut', 'Fairfield County'): 1,
#  ('North America', 'USA', 'Illinois', 'Chicago'): 92,
#  ('North America', 'USA', 'Indiana', 'Indianapolis'): 6,
#  ('North America', 'USA', 'Iowa', 'Allamakee County'): 13,
#  ('North America', 'USA', 'Iowa', 'Buchanan County'): 1,
#  ('North America', 'USA', 'Iowa', 'Fayette County'): 1,
#  ('North America', 'USA', 'Iowa', 'Winneshiek County'): 3,
#  ('North America', 'USA', 'Louisiana', 'New Orleans'): 112,
#  ('North America', 'USA', 'Minnesota', 'Fillmore County'): 2,
#  ('North America', 'USA', 'Minnesota', 'Winona County'): 4,
#  ('North America', 'USA', 'New Jersey', 'Bergen County'): 5,
#  ('North America', 'USA', 'New Jersey', 'Camden County'): 1,
#  ('North America', 'USA', 'New Jersey', 'Essex County'): 1,
#  ('North America', 'USA', 'New Jersey', 'Hudson County'): 11,
#  ('North America', 'USA', 'New York', 'Albany County'): 1,
#  ('North America', 'USA', 'New York', 'Broome County'): 1,
#  ('North America', 'USA', 'New York', 'Cayuga County'): 1,
#  ('North America', 'USA', 'New York', 'Chenango County'): 1,
#  ('North America', 'USA', 'New York', 'Clinton County'): 1,
#  ('North America', 'USA', 'New York', 'Dutchess County'): 1,
#  ('North America', 'USA', 'New York', 'Franklin County'): 1,
#  ('North America', 'USA', 'New York', 'Jefferson County'): 1,
#  ('North America', 'USA', 'New York', 'Montgomery County'): 1,
#  ('North America', 'USA', 'New York', 'Nassau County'): 195,
#  ('North America', 'USA', 'New York', 'New York City'): 1060,
#  ('North America', 'USA', 'New York', 'Onondaga County'): 3,
#  ('North America', 'USA', 'New York', 'Orange County'): 2,
#  ('North America', 'USA', 'New York', 'Passaic County'): 1,
#  ('North America', 'USA', 'New York', 'Putnam County'): 1,
#  ('North America', 'USA', 'New York', 'Richmond County'): 1,
#  ('North America', 'USA', 'New York', 'Rockland County'): 5,
#  ('North America', 'USA', 'New York', 'Saratoga County'): 2,
#  ('North America', 'USA', 'New York', 'Schenectady County'): 2,
#  ('North America', 'USA', 'New York', 'Suffolk County'): 24,
#  ('North America', 'USA', 'New York', 'Ulster County'): 2,
#  ('North America', 'USA', 'New York', 'Washington County'): 1,
#  ('North America', 'USA', 'New York', 'Westchester County'): 19,
#  ('North America', 'USA', 'Ohio', 'Columbus'): 6,
#  ('North America', 'USA', 'Oregon', 'Columbia County'): 1,
#  ('North America', 'USA', 'Oregon', 'Multnomah County'): 4,
#  ('North America', 'USA', 'Oregon', 'Wasco County'): 1,
#  ('North America', 'USA', 'Oregon', 'Washington County'): 10,
#  ('North America', 'USA', 'Pennsylvania', 'Pittsburgh'): 98,
#  ('North America', 'USA', 'Texas', 'Houston'): 8,
#  ('North America', 'USA', 'Washington', 'Adams County'): 7,
#  ('North America', 'USA', 'Washington', 'Asotin County'): 9,
#  ('North America', 'USA', 'Washington', 'Benton County'): 2,
#  ('North America', 'USA', 'Washington', 'Clark County'): 3,
#  ('North America', 'USA', 'Washington', 'Franklin County'): 5,
#  ('North America', 'USA', 'Washington', 'Grant County'): 5,
#  ('North America', 'USA', 'Washington', 'Jefferson County'): 1,
#  ('North America', 'USA', 'Washington', 'King County'): 287,
#  ('North America', 'USA', 'Washington', 'Kittitas County'): 1,
#  ('North America', 'USA', 'Washington', 'Mason County'): 3,
#  ('North America', 'USA', 'Washington', 'Pierce County'): 70,
#  ('North America', 'USA', 'Washington', 'Skagit County'): 12,
#  ('North America', 'USA', 'Washington', 'Snohomish County'): 75,
#  ('North America', 'USA', 'Washington', 'Thurston County'): 1,
#  ('North America', 'USA', 'Washington', 'Umatilla County'): 2,
#  ('North America', 'USA', 'Washington', 'Whatcom County'): 45,
#  ('North America', 'USA', 'Washington', 'Yakima County'): 249,
#  ('North America', 'USA', 'Wisconsin', 'Adams County'): 1,
#  ('North America', 'USA', 'Wisconsin', 'Chippewa County'): 1,
#  ('North America', 'USA', 'Wisconsin', 'Columbia County'): 2,
#  ('North America', 'USA', 'Wisconsin', 'Crawford County'): 1,
#  ('North America', 'USA', 'Wisconsin', 'Dane County'): 124,
#  ('North America', 'USA', 'Wisconsin', 'Fond du Lac County'): 1,
#  ('North America', 'USA', 'Wisconsin', 'Grant County'): 2,
#  ('North America', 'USA', 'Wisconsin', 'Jackson County'): 2,
#  ('North America', 'USA', 'Wisconsin', 'Juneau County'): 2,
#  ('North America', 'USA', 'Wisconsin', 'La Crosse County'): 14,
#  ('North America', 'USA', 'Wisconsin', 'Lafayette County'): 1,
#  ('North America', 'USA', 'Wisconsin', 'Milwaukee County'): 139,
#  ('North America', 'USA', 'Wisconsin', 'Monroe County'): 3,
#  ('North America', 'USA', 'Wisconsin', 'Ozaukee County'): 20,
#  ('North America', 'USA', 'Wisconsin', 'Racine County'): 1,
#  ('North America', 'USA', 'Wisconsin', 'Richland County'): 1,
#  ('North America', 'USA', 'Wisconsin', 'Rock County'): 2,
#  ('North America', 'USA', 'Wisconsin', 'Sauk County'): 2,
#  ('North America', 'USA', 'Wisconsin', 'Trempealeau County'): 3,
#  ('North America', 'USA', 'Wisconsin', 'Vernon County'): 4,
#  ('North America', 'USA', 'Wisconsin', 'Washington County'): 2,
#  ('North America', 'USA', 'Wisconsin', 'Waukesha County'): 8,
#  ('Oceania', 'Australia', 'New South Wales', 'Sydney'): 437,
#  ('Oceania', 'Australia', 'New South Wales', 'Tweed Heads'): 1,
#  ('Oceania', 'Australia', 'Queensland', 'Brisbane'): 10,
#  ('Oceania', 'Australia', 'Queensland', 'Cairns'): 1,
#  ('Oceania', 'Australia', 'Queensland', 'Gold Coast'): 3,
#  ('Oceania', 'Australia', 'Queensland', 'Northern Queensland'): 1,
#  ('Oceania', 'Australia', 'Queensland', 'Rockhampton'): 1,
#  ('Oceania', 'Australia', 'Queensland', 'Southeast Queensland'): 1,
#  ('Oceania', 'Australia', 'Queensland', 'Sunshine Coast'): 4,
#  ('Oceania', 'Australia', 'Victoria', 'Clayton'): 2,
#  ('Oceania', 'Australia', 'Victoria', 'Melbourne'): 11,
#  ('Oceania', 'Australia', 'Western Australia', 'Perth'): 8,
#  ('South America', 'Brazil', 'Alagoas', 'Maceio'): 1,
#  ('South America', 'Brazil', 'Amazonas State', 'Manaus'): 1,
#  ('South America', 'Brazil', 'Bahia', 'Feira de Santana'): 2,
#  ('South America', 'Brazil', 'Distrito Federal', 'Brasilia'): 7,
#  ('South America', 'Brazil', 'Espirito Santo', 'Vila Velha'): 1,
#  ('South America', 'Brazil', 'Rio de Janeiro', 'Belford Roxo'): 1,
#  ('South America', 'Brazil', 'Rio de Janeiro', 'Duque de Caxias'): 1,
#  ('South America', 'Brazil', 'Rio de Janeiro', 'Itaborai'): 1,
#  ('South America', 'Brazil', 'Rio de Janeiro', 'Niteroi'): 1,
#  ('South America', 'Brazil', 'Rio de Janeiro', 'Nova Iguacu'): 2,
#  ('South America', 'Brazil', 'Rio de Janeiro', 'Petropolis'): 1,
#  ('South America', 'Brazil', 'Rio de Janeiro', 'Rio de Janeiro'): 35,
#  ('South America', 'Brazil', 'Rio de Janeiro', 'Teresopolis'): 1,
#  ('South America', 'Brazil', 'Santa Catarina', 'Florianopolis'): 1,
#  ('South America', 'Brazil', 'Santa Catarina', 'Joinville'): 1,
#  ('South America', 'Colombia', 'Amazonas', 'Leticia'): 1,
#  ('South America', 'Colombia', 'Antioquia', 'Bello'): 1,
#  ('South America', 'Colombia', 'Antioquia', 'Envigado'): 1,
#  ('South America', 'Colombia', 'Antioquia', 'Itagui'): 1,
#  ('South America', 'Colombia', 'Antioquia', 'Medellin'): 8,
#  ('South America', 'Colombia', 'Antioquia', 'Sabaneta'): 1,
#  ('South America', 'Colombia', 'Atlantico', 'Barranquilla'): 1,
#  ('South America', 'Colombia', 'Bolivar', 'Cartagena'): 3,
#  ('South America', 'Colombia', 'Boyaca', 'Santa Sofia'): 1,
#  ('South America', 'Colombia', 'Boyaca', 'Santana'): 1,
#  ('South America', 'Colombia', 'Boyaca', 'Togui'): 7,
#  ('South America', 'Colombia', 'Caldas', 'Anserma'): 1,
#  ('South America', 'Colombia', 'Caldas', 'Manizales'): 1,
#  ('South America', 'Colombia', 'Caldas', 'Pereira'): 1,
#  ('South America', 'Colombia', 'Cauca', 'Popayan'): 1,
#  ('South America', 'Colombia', 'Cesar', 'Valledupar'): 1,
#  ('South America', 'Colombia', 'Choco', 'Quibdo'): 1,
#  ('South America', 'Colombia', 'Cordoba', 'Monteria'): 1,
#  ('South America', 'Colombia', 'Cordoba', 'Tierralta'): 1,
#  ('South America', 'Colombia', 'Cundinamarca', 'Cajica'): 1,
#  ('South America', 'Colombia', 'Cundinamarca', 'Choconta'): 1,
#  ('South America', 'Colombia', 'Cundinamarca', 'Funza'): 1,
#  ('South America', 'Colombia', 'Cundinamarca', 'Madrid'): 1,
#  ('South America', 'Colombia', 'Cundinamarca', 'Pacho'): 1,
#  ('South America', 'Colombia', 'Cundinamarca', 'Soacha'): 2,
#  ('South America', 'Colombia', 'Cundinamarca', 'Zipaquira'): 2,
#  ('South America', 'Colombia', 'Huila', 'Neiva'): 7,
#  ('South America', 'Colombia', 'Magdalena', 'Cienaga'): 1,
#  ('South America', 'Colombia', 'Magdalena', 'Santa Marta'): 3,
#  ('South America', 'Colombia', 'Meta', 'Villavicencio'): 3,
#  ('South America', 'Colombia', 'Narino', 'Ipiales'): 3,
#  ('South America', 'Colombia', 'Narino', 'Tumaco'): 1,
#  ('South America', 'Colombia', 'Norte de Santander', 'Cucuta'): 3,
#  ('South America', 'Colombia', 'Quindio', 'Armenia'): 2,
#  ('South America', 'Colombia', 'Risaralda', 'Dosquebradas'): 1,
#  ('South America', 'Colombia', 'Risaralda', 'Pereira'): 4,
#  ('South America', 'Colombia', 'Santander', 'Barrancabermeja'): 1,
#  ('South America', 'Colombia', 'Santander', 'Bucaramanga'): 2,
#  ('South America', 'Colombia', 'Tolima', 'Ibague'): 3,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Andalucia'): 1,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Ansermo'): 1,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Buga'): 2,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Cali'): 31,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Cartago'): 1,
#  ('South America', 'Colombia', 'Valle del Cauca', 'El Cerrito'): 2,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Jamundi'): 1,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Palmira'): 3,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Trujillo'): 1,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Tulua'): 3,
#  ('South America', 'Colombia', 'Valle del Cauca', 'Yumbo'): 1}

# %%
unique_location_df = pd.read_csv('/Volumes/GoogleDrive/My Drive/covid_data/location_map.csv')
unique_location_df
# Out:
#       index         region                           country         division  \
# 0         0         Africa                           Algeria            Blida
# 1         1         Africa                           Algeria         Boufarik
# 2         2         Africa  Democratic Republic of the Congo               -1
# 3         3         Africa  Democratic Republic of the Congo         Kinshasa
# 4         4         Africa  Democratic Republic of the Congo         Sud Kivu
# ...     ...            ...                               ...              ...
# 1006   1006  South America                          Colombia  Valle del Cauca
# 1007   1007  South America                           Ecuador        Pichincha
# 1008   1008  South America                           Ecuador            Quito
# 1009   1009  South America                              Peru             Lima
# 1010   1010  South America                           Uruguay       Montevideo
#
#      location
# 0          -1
# 1          -1
# 2          -1
# 3          -1
# 4          -1
# ...       ...
# 1006    Yumbo
# 1007       -1
# 1008       -1
# 1009       -1
# 1010       -1
#
# [1011 rows x 5 columns]

# %% [markdown]
# # Find a way to condense numbers

# %%
region_counts
# Out:
# {'Africa': 359,
#  'Asia': 3038,
#  'Europe': 23941,
#  'North America': 7431,
#  'Oceania': 2146,
#  'South America': 482}

# %%
# Thanks to user "rtaft" from https://stackoverflow.com/questions/579310/formatting-long-numbers-as-strings-in-python
def human_format(num):
    num = float('{:.3g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0').rstrip('.'), ['', 'K', 'M', 'B', 'T'][magnitude])

human_format(23941)
# Out:
# '23.9K'

# %% [markdown]
# # Inject counts into location tree

# %%
region_counts = dict(df.groupby('region')['gisaid_id'].count())
country_counts = dict(df.groupby(['region', 'country'])['gisaid_id'].count())
division_counts = dict(df.groupby(['region', 'country', 'division'])['gisaid_id'].count())
location_counts = dict(df.groupby(['region', 'country', 'division', 'location'])['gisaid_id'].count())

# %%
# Root node
select_tree = {
    'label': 'All',
    'value': 'All',
    'children': []
}

for i, loc in unique_location_df.iterrows():
    # Add region node
    if loc['region'] == '-1':
        continue

    region_node = [c for c in select_tree['children'] if c['value'] == loc['region']]
    if region_node:
        region_node = region_node[0]
    else:
        region_node = {
            'label': loc['region'],
            'value': loc['region'],
            'level': 'region',
            'actions': [{
                'className': 'fa fa-info',
                'title': region_counts[loc['region']],
                'text': human_format(region_counts[loc['region']])
            }],
            'children': []
        }
        select_tree['children'].append(region_node)

    # Add country --> region
    if loc['country'] == '-1':
        continue

    country_node = [c for c in region_node['children'] if c['value'] == loc['country']]
    if country_node:
        country_node = country_node[0]
    else:
        country_node = {
            'label': loc['country'],
            'value': loc['country'],
            'region': loc['region'],
            'level': 'country',
            'actions': [{
                'className': 'fa fa-info',
                'title': country_counts[(loc['region'], loc['country'])],
                'text': human_format(country_counts[(loc['region'], loc['country'])])
            }],
            'children': []
        }
        region_node['children'].append(country_node)

    # Add division --> country
    if loc['division'] == '-1':
        continue

    division_node = [c for c in country_node['children'] if c['value'] == loc['division']]
    if division_node:
        division_node = division_node[0]
    else:
        division_node = {
            'label': loc['division'],
            'value': loc['division'],
            'region': loc['region'],
            'country': loc['country'],
            'level': 'division',
            'actions': [{
                'className': 'fa fa-info',
                'title': division_counts[(loc['region'], loc['country'], loc['division'])],
                'text': human_format(division_counts[(loc['region'], loc['country'], loc['division'])])
            }],
            'children': []
        }
        country_node['children'].append(division_node)

    # Add location --> division
    if loc['location'] == '-1':
        continue

    location_node = [c for c in division_node['children'] if c['value'] == loc['location']]
    if location_node:
        location_node = location_node[0]
    else:
        location_node = {
            'label': loc['location'],
            'value': loc['location'],
            'region': loc['region'],
            'country': loc['country'],
            'division': loc['division'],
            'level': 'location',
            'actions': [{
                'className': 'fa fa-info',
                'title': location_counts[(loc['region'], loc['country'], loc['division'], loc['location'])],
                'text': human_format(location_counts[(loc['region'], loc['country'], loc['division'], loc['location'])])
            }],
            'children': []
        }
        division_node['children'].append(location_node)
        
select_tree
# Out:
# {'label': 'All',
#  'value': 'All',
#  'children': [{'label': 'Africa',
#    'value': 'Africa',
#    'level': 'region',
#    'actions': [{'className': 'fa fa-info', 'title': 359, 'text': '359'}],
#    'children': [{'label': 'Algeria',
#      'value': 'Algeria',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#      'children': [{'label': 'Blida',
#        'value': 'Blida',
#        'region': 'Africa',
#        'country': 'Algeria',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Boufarik',
#        'value': 'Boufarik',
#        'region': 'Africa',
#        'country': 'Algeria',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []}]},
#     {'label': 'Democratic Republic of the Congo',
#      'value': 'Democratic Republic of the Congo',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 133, 'text': '133'}],
#      'children': [{'label': 'Kinshasa',
#        'value': 'Kinshasa',
#        'region': 'Africa',
#        'country': 'Democratic Republic of the Congo',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 130, 'text': '130'}],
#        'children': []},
#       {'label': 'Sud Kivu',
#        'value': 'Sud Kivu',
#        'region': 'Africa',
#        'country': 'Democratic Republic of the Congo',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []}]},
#     {'label': 'Egypt',
#      'value': 'Egypt',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#      'children': []},
#     {'label': 'Gambia',
#      'value': 'Gambia',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#      'children': [{'label': 'West Coast Region',
#        'value': 'West Coast Region',
#        'region': 'Africa',
#        'country': 'Gambia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#        'children': []}]},
#     {'label': 'Ghana',
#      'value': 'Ghana',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 15, 'text': '15'}],
#      'children': [{'label': 'Greater Accra',
#        'value': 'Greater Accra',
#        'region': 'Africa',
#        'country': 'Ghana',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 15, 'text': '15'}],
#        'children': []}]},
#     {'label': 'Kenya',
#      'value': 'Kenya',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 112, 'text': '112'}],
#      'children': []},
#     {'label': 'Nigeria',
#      'value': 'Nigeria',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 17, 'text': '17'}],
#      'children': [{'label': 'Kwara State',
#        'value': 'Kwara State',
#        'region': 'Africa',
#        'country': 'Nigeria',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Lagos',
#        'value': 'Lagos',
#        'region': 'Africa',
#        'country': 'Nigeria',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Ogun State',
#        'value': 'Ogun State',
#        'region': 'Africa',
#        'country': 'Nigeria',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Osun State',
#        'value': 'Osun State',
#        'region': 'Africa',
#        'country': 'Nigeria',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#        'children': []},
#       {'label': 'Oyo State',
#        'value': 'Oyo State',
#        'region': 'Africa',
#        'country': 'Nigeria',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#        'children': []}]},
#     {'label': 'Senegal',
#      'value': 'Senegal',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 23, 'text': '23'}],
#      'children': [{'label': 'Dakar',
#        'value': 'Dakar',
#        'region': 'Africa',
#        'country': 'Senegal',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#        'children': []},
#       {'label': 'Mbour',
#        'value': 'Mbour',
#        'region': 'Africa',
#        'country': 'Senegal',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#        'children': []},
#       {'label': 'St-Louis',
#        'value': 'St-Louis',
#        'region': 'Africa',
#        'country': 'Senegal',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Thies',
#        'value': 'Thies',
#        'region': 'Africa',
#        'country': 'Senegal',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Touba',
#        'value': 'Touba',
#        'region': 'Africa',
#        'country': 'Senegal',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 6, 'text': '6'}],
#        'children': []}]},
#     {'label': 'South Africa',
#      'value': 'South Africa',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 31, 'text': '31'}],
#      'children': [{'label': 'Eastern Cape',
#        'value': 'Eastern Cape',
#        'region': 'Africa',
#        'country': 'South Africa',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Gauteng',
#        'value': 'Gauteng',
#        'region': 'Africa',
#        'country': 'South Africa',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#        'children': []},
#       {'label': 'KwaZulu-Natal',
#        'value': 'KwaZulu-Natal',
#        'region': 'Africa',
#        'country': 'South Africa',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 24, 'text': '24'}],
#        'children': []},
#       {'label': 'Limpopo',
#        'value': 'Limpopo',
#        'region': 'Africa',
#        'country': 'South Africa',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Mpumalanga',
#        'value': 'Mpumalanga',
#        'region': 'Africa',
#        'country': 'South Africa',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []}]},
#     {'label': 'Uganda',
#      'value': 'Uganda',
#      'region': 'Africa',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 20, 'text': '20'}],
#      'children': []}]},
#   {'label': 'Asia',
#    'value': 'Asia',
#    'level': 'region',
#    'actions': [{'className': 'fa fa-info', 'title': 3038, 'text': '3.04K'}],
#    'children': [{'label': 'Bangladesh',
#      'value': 'Bangladesh',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 24, 'text': '24'}],
#      'children': [{'label': 'Chattogram',
#        'value': 'Chattogram',
#        'region': 'Asia',
#        'country': 'Bangladesh',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 7, 'text': '7'}],
#        'children': []},
#       {'label': 'Chuandanga',
#        'value': 'Chuandanga',
#        'region': 'Asia',
#        'country': 'Bangladesh',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': [{'label': 'Sadar',
#          'value': 'Sadar',
#          'region': 'Asia',
#          'country': 'Bangladesh',
#          'division': 'Chuandanga',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Dhaka',
#        'value': 'Dhaka',
#        'region': 'Asia',
#        'country': 'Bangladesh',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 13, 'text': '13'}],
#        'children': []},
#       {'label': 'Jhenaidha',
#        'value': 'Jhenaidha',
#        'region': 'Asia',
#        'country': 'Bangladesh',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': [{'label': 'Shailokupa',
#          'value': 'Shailokupa',
#          'region': 'Asia',
#          'country': 'Bangladesh',
#          'division': 'Jhenaidha',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Narayanganj',
#        'value': 'Narayanganj',
#        'region': 'Asia',
#        'country': 'Bangladesh',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []}]},
#     {'label': 'Brunei',
#      'value': 'Brunei',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 5, 'text': '5'}],
#      'children': []},
#     {'label': 'China',
#      'value': 'China',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 805, 'text': '805'}],
#      'children': [{'label': 'Anhui',
#        'value': 'Anhui',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': [{'label': 'Fuyang',
#          'value': 'Fuyang',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Anhui',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Suzhou',
#          'value': 'Suzhou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Anhui',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Beijing',
#        'value': 'Beijing',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 73, 'text': '73'}],
#        'children': []},
#       {'label': 'Fujian',
#        'value': 'Fujian',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#        'children': []},
#       {'label': 'Guangdong',
#        'value': 'Guangdong',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 183, 'text': '183'}],
#        'children': [{'label': 'Dongguan',
#          'value': 'Dongguan',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#          'children': []},
#         {'label': 'Foshan',
#          'value': 'Foshan',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 7, 'text': '7'}],
#          'children': []},
#         {'label': 'Guangzhou',
#          'value': 'Guangzhou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 61, 'text': '61'}],
#          'children': []},
#         {'label': 'Huizhou',
#          'value': 'Huizhou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 10, 'text': '10'}],
#          'children': []},
#         {'label': 'Meizhou',
#          'value': 'Meizhou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Shantou',
#          'value': 'Shantou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Shanwei',
#          'value': 'Shanwei',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Shaoguan',
#          'value': 'Shaoguan',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Shenzhen',
#          'value': 'Shenzhen',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 25, 'text': '25'}],
#          'children': []},
#         {'label': 'Yangjiang',
#          'value': 'Yangjiang',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Zhanjiang',
#          'value': 'Zhanjiang',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Zhongshan',
#          'value': 'Zhongshan',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Zhuhai',
#          'value': 'Zhuhai',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Guangdong',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#          'children': []}]},
#       {'label': 'Hubei',
#        'value': 'Hubei',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 220, 'text': '220'}],
#        'children': [{'label': 'Tianmen',
#          'value': 'Tianmen',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Hubei',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Wuhan',
#          'value': 'Wuhan',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Hubei',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 219, 'text': '219'}],
#          'children': []}]},
#       {'label': 'Jiangsu',
#        'value': 'Jiangsu',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': [{'label': 'Changzhou',
#          'value': 'Changzhou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangsu',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Jiangxi',
#        'value': 'Jiangxi',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 34, 'text': '34'}],
#        'children': [{'label': 'Fuzhou',
#          'value': 'Fuzhou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Ganzhou',
#          'value': 'Ganzhou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Jian',
#          'value': 'Jian',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Jiujiang',
#          'value': 'Jiujiang',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Nanchang',
#          'value': 'Nanchang',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 10, 'text': '10'}],
#          'children': []},
#         {'label': 'Pingxiang',
#          'value': 'Pingxiang',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Shangrao',
#          'value': 'Shangrao',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 8, 'text': '8'}],
#          'children': []},
#         {'label': 'Xinyu',
#          'value': 'Xinyu',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Yichun',
#          'value': 'Yichun',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Yingtan',
#          'value': 'Yingtan',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Jiangxi',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Shandong',
#        'value': 'Shandong',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 8, 'text': '8'}],
#        'children': []},
#       {'label': 'Shanghai',
#        'value': 'Shanghai',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 95, 'text': '95'}],
#        'children': []},
#       {'label': 'Sichuan',
#        'value': 'Sichuan',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 89, 'text': '89'}],
#        'children': []},
#       {'label': 'Yunnan',
#        'value': 'Yunnan',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 5, 'text': '5'}],
#        'children': [{'label': "Pu'er",
#          'value': "Pu'er",
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Yunnan',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Xishuangbanna',
#          'value': 'Xishuangbanna',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Yunnan',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []}]},
#       {'label': 'Zhejiang',
#        'value': 'Zhejiang',
#        'region': 'Asia',
#        'country': 'China',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 62, 'text': '62'}],
#        'children': [{'label': 'Hangzhou',
#          'value': 'Hangzhou',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Zhejiang',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 42, 'text': '42'}],
#          'children': []},
#         {'label': 'Lishui',
#          'value': 'Lishui',
#          'region': 'Asia',
#          'country': 'China',
#          'division': 'Zhejiang',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#          'children': []}]}]},
#     {'label': 'Georgia',
#      'value': 'Georgia',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 15, 'text': '15'}],
#      'children': [{'label': 'Tbilisi',
#        'value': 'Tbilisi',
#        'region': 'Asia',
#        'country': 'Georgia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 15, 'text': '15'}],
#        'children': []}]},
#     {'label': 'Hong Kong',
#      'value': 'Hong Kong',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 140, 'text': '140'}],
#      'children': []},
#     {'label': 'India',
#      'value': 'India',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 561, 'text': '561'}],
#      'children': [{'label': 'Andhra Pradesh',
#        'value': 'Andhra Pradesh',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'Assam',
#        'value': 'Assam',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'Bihar',
#        'value': 'Bihar',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 6, 'text': '6'}],
#        'children': []},
#       {'label': 'Delhi',
#        'value': 'Delhi',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 39, 'text': '39'}],
#        'children': []},
#       {'label': 'Gujarat',
#        'value': 'Gujarat',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 143, 'text': '143'}],
#        'children': [{'label': 'Ahmedabad',
#          'value': 'Ahmedabad',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 60, 'text': '60'}],
#          'children': []},
#         {'label': 'Botad',
#          'value': 'Botad',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Dahegam',
#          'value': 'Dahegam',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Dahod',
#          'value': 'Dahod',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#          'children': []},
#         {'label': 'Dhansura',
#          'value': 'Dhansura',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Gandhinagar',
#          'value': 'Gandhinagar',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 13, 'text': '13'}],
#          'children': []},
#         {'label': 'Himatnagar',
#          'value': 'Himatnagar',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Jamnagar',
#          'value': 'Jamnagar',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 6, 'text': '6'}],
#          'children': []},
#         {'label': 'Junagadh',
#          'value': 'Junagadh',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Kodinar',
#          'value': 'Kodinar',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Mansa',
#          'value': 'Mansa',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Modasa',
#          'value': 'Modasa',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 13, 'text': '13'}],
#          'children': []},
#         {'label': 'Prantij',
#          'value': 'Prantij',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Rajkot',
#          'value': 'Rajkot',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 5, 'text': '5'}],
#          'children': []},
#         {'label': 'Surat',
#          'value': 'Surat',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 7, 'text': '7'}],
#          'children': []},
#         {'label': 'Una',
#          'value': 'Una',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Vadodara',
#          'value': 'Vadodara',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Gujarat',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 17, 'text': '17'}],
#          'children': []}]},
#       {'label': 'Haryana',
#        'value': 'Haryana',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#        'children': []},
#       {'label': 'Jammu and Kashmir',
#        'value': 'Jammu and Kashmir',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': [{'label': 'Jammu',
#          'value': 'Jammu',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Jammu and Kashmir',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Karnataka',
#        'value': 'Karnataka',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 17, 'text': '17'}],
#        'children': []},
#       {'label': 'Kerala',
#        'value': 'Kerala',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'Ladakh',
#        'value': 'Ladakh',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 7, 'text': '7'}],
#        'children': [{'label': 'Kargil',
#          'value': 'Kargil',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Ladakh',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Madhya Pradesh',
#        'value': 'Madhya Pradesh',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 19, 'text': '19'}],
#        'children': []},
#       {'label': 'Maharashtra',
#        'value': 'Maharashtra',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 88, 'text': '88'}],
#        'children': [{'label': 'Mumbai',
#          'value': 'Mumbai',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Maharashtra',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []}]},
#       {'label': 'Odisha',
#        'value': 'Odisha',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 46, 'text': '46'}],
#        'children': []},
#       {'label': 'Punjab',
#        'value': 'Punjab',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Rajasthan',
#        'value': 'Rajasthan',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 6, 'text': '6'}],
#        'children': [{'label': 'Bikaner',
#          'value': 'Bikaner',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Rajasthan',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Jaipur',
#          'value': 'Jaipur',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Rajasthan',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#          'children': []}]},
#       {'label': 'Tamil Nadu',
#        'value': 'Tamil Nadu',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 19, 'text': '19'}],
#        'children': []},
#       {'label': 'Telangana',
#        'value': 'Telangana',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 62, 'text': '62'}],
#        'children': [{'label': 'Hyderabad',
#          'value': 'Hyderabad',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Telangana',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 7, 'text': '7'}],
#          'children': []}]},
#       {'label': 'Uttar Pradesh',
#        'value': 'Uttar Pradesh',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 5, 'text': '5'}],
#        'children': [{'label': 'Noida',
#          'value': 'Noida',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'Uttar Pradesh',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'West Bengal',
#        'value': 'West Bengal',
#        'region': 'Asia',
#        'country': 'India',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 52, 'text': '52'}],
#        'children': [{'label': 'Darjeeling',
#          'value': 'Darjeeling',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'West Bengal',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'East Medinipur',
#          'value': 'East Medinipur',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'West Bengal',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 6, 'text': '6'}],
#          'children': []},
#         {'label': 'Howrah',
#          'value': 'Howrah',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'West Bengal',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Kolkata',
#          'value': 'Kolkata',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'West Bengal',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 21, 'text': '21'}],
#          'children': []},
#         {'label': 'North 24 Parganas',
#          'value': 'North 24 Parganas',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'West Bengal',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 6, 'text': '6'}],
#          'children': []},
#         {'label': 'South 24 Parganas',
#          'value': 'South 24 Parganas',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'West Bengal',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 10, 'text': '10'}],
#          'children': []},
#         {'label': 'Tehatta',
#          'value': 'Tehatta',
#          'region': 'Asia',
#          'country': 'India',
#          'division': 'West Bengal',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]}]},
#     {'label': 'Indonesia',
#      'value': 'Indonesia',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 19, 'text': '19'}],
#      'children': [{'label': 'Depok',
#        'value': 'Depok',
#        'region': 'Asia',
#        'country': 'Indonesia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Jakarta',
#        'value': 'Jakarta',
#        'region': 'Asia',
#        'country': 'Indonesia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#        'children': []},
#       {'label': 'Surabaya',
#        'value': 'Surabaya',
#        'region': 'Asia',
#        'country': 'Indonesia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'Tangerang',
#        'value': 'Tangerang',
#        'region': 'Asia',
#        'country': 'Indonesia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#        'children': []},
#       {'label': 'West Java',
#        'value': 'West Java',
#        'region': 'Asia',
#        'country': 'Indonesia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': [{'label': 'Indramayu',
#          'value': 'Indramayu',
#          'region': 'Asia',
#          'country': 'Indonesia',
#          'division': 'West Java',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]}]},
#     {'label': 'Iran',
#      'value': 'Iran',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 34, 'text': '34'}],
#      'children': [{'label': 'Qom',
#        'value': 'Qom',
#        'region': 'Asia',
#        'country': 'Iran',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 9, 'text': '9'}],
#        'children': []},
#       {'label': 'Semnan',
#        'value': 'Semnan',
#        'region': 'Asia',
#        'country': 'Iran',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Tehran',
#        'value': 'Tehran',
#        'region': 'Asia',
#        'country': 'Iran',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#        'children': [{'label': 'Nazi Abad',
#          'value': 'Nazi Abad',
#          'region': 'Asia',
#          'country': 'Iran',
#          'division': 'Tehran',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]}]},
#     {'label': 'Israel',
#      'value': 'Israel',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 222, 'text': '222'}],
#      'children': [{'label': 'Jerusalem District',
#        'value': 'Jerusalem District',
#        'region': 'Asia',
#        'country': 'Israel',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 60, 'text': '60'}],
#        'children': []},
#       {'label': 'North District',
#        'value': 'North District',
#        'region': 'Asia',
#        'country': 'Israel',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 29, 'text': '29'}],
#        'children': []},
#       {'label': 'Ramat Gan',
#        'value': 'Ramat Gan',
#        'region': 'Asia',
#        'country': 'Israel',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'South District',
#        'value': 'South District',
#        'region': 'Asia',
#        'country': 'Israel',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 71, 'text': '71'}],
#        'children': []},
#       {'label': 'Tel Aviv District',
#        'value': 'Tel Aviv District',
#        'region': 'Asia',
#        'country': 'Israel',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 52, 'text': '52'}],
#        'children': []}]},
#     {'label': 'Japan',
#      'value': 'Japan',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 123, 'text': '123'}],
#      'children': [{'label': 'Chiba',
#        'value': 'Chiba',
#        'region': 'Asia',
#        'country': 'Japan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 5, 'text': '5'}],
#        'children': []},
#       {'label': 'Ishikawa',
#        'value': 'Ishikawa',
#        'region': 'Asia',
#        'country': 'Japan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'Kanagawa',
#        'value': 'Kanagawa',
#        'region': 'Asia',
#        'country': 'Japan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'Kanto',
#        'value': 'Kanto',
#        'region': 'Asia',
#        'country': 'Japan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 24, 'text': '24'}],
#        'children': []},
#       {'label': 'Kochi',
#        'value': 'Kochi',
#        'region': 'Asia',
#        'country': 'Japan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Saitama',
#        'value': 'Saitama',
#        'region': 'Asia',
#        'country': 'Japan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 10, 'text': '10'}],
#        'children': []},
#       {'label': 'Tokyo',
#        'value': 'Tokyo',
#        'region': 'Asia',
#        'country': 'Japan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []}]},
#     {'label': 'Jordan',
#      'value': 'Jordan',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 28, 'text': '28'}],
#      'children': [{'label': 'Amman',
#        'value': 'Amman',
#        'region': 'Asia',
#        'country': 'Jordan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 26, 'text': '26'}],
#        'children': []},
#       {'label': 'Irbid',
#        'value': 'Irbid',
#        'region': 'Asia',
#        'country': 'Jordan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []}]},
#     {'label': 'Kazakhstan',
#      'value': 'Kazakhstan',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 53, 'text': '53'}],
#      'children': [{'label': 'Nur-Sultan',
#        'value': 'Nur-Sultan',
#        'region': 'Asia',
#        'country': 'Kazakhstan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 53, 'text': '53'}],
#        'children': []}]},
#     {'label': 'Kuwait',
#      'value': 'Kuwait',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 8, 'text': '8'}],
#      'children': [{'label': 'Dasman',
#        'value': 'Dasman',
#        'region': 'Asia',
#        'country': 'Kuwait',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 7, 'text': '7'}],
#        'children': []},
#       {'label': 'Hawali',
#        'value': 'Hawali',
#        'region': 'Asia',
#        'country': 'Kuwait',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []}]},
#     {'label': 'Lebanon',
#      'value': 'Lebanon',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#      'children': [{'label': 'Beirut',
#        'value': 'Beirut',
#        'region': 'Asia',
#        'country': 'Lebanon',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 11, 'text': '11'}],
#        'children': []}]},
#     {'label': 'Malaysia',
#      'value': 'Malaysia',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 22, 'text': '22'}],
#      'children': [{'label': 'Kuala Lumpur',
#        'value': 'Kuala Lumpur',
#        'region': 'Asia',
#        'country': 'Malaysia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#        'children': []},
#       {'label': 'Pahang',
#        'value': 'Pahang',
#        'region': 'Asia',
#        'country': 'Malaysia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'Selangor',
#        'value': 'Selangor',
#        'region': 'Asia',
#        'country': 'Malaysia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 10, 'text': '10'}],
#        'children': []}]},
#     {'label': 'Myanmar',
#      'value': 'Myanmar',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#      'children': []},
#     {'label': 'Oman',
#      'value': 'Oman',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 35, 'text': '35'}],
#      'children': [{'label': 'Buraimi',
#        'value': 'Buraimi',
#        'region': 'Asia',
#        'country': 'Oman',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Dakhiliyah',
#        'value': 'Dakhiliyah',
#        'region': 'Asia',
#        'country': 'Oman',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Muscat',
#        'value': 'Muscat',
#        'region': 'Asia',
#        'country': 'Oman',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 29, 'text': '29'}],
#        'children': []},
#       {'label': 'North Batinah',
#        'value': 'North Batinah',
#        'region': 'Asia',
#        'country': 'Oman',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []},
#       {'label': 'South Batinah',
#        'value': 'South Batinah',
#        'region': 'Asia',
#        'country': 'Oman',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []}]},
#     {'label': 'Pakistan',
#      'value': 'Pakistan',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#      'children': [{'label': 'Gilgit',
#        'value': 'Gilgit',
#        'region': 'Asia',
#        'country': 'Pakistan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Karachi',
#        'value': 'Karachi',
#        'region': 'Asia',
#        'country': 'Pakistan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []},
#       {'label': 'Khyber Pakhtunkhwa',
#        'value': 'Khyber Pakhtunkhwa',
#        'region': 'Asia',
#        'country': 'Pakistan',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []}]},
#     {'label': 'Philippines',
#      'value': 'Philippines',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 13, 'text': '13'}],
#      'children': [{'label': 'Manila',
#        'value': 'Manila',
#        'region': 'Asia',
#        'country': 'Philippines',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 6, 'text': '6'}],
#        'children': []}]},
#     {'label': 'Qatar',
#      'value': 'Qatar',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 16, 'text': '16'}],
#      'children': [{'label': 'Doha',
#        'value': 'Doha',
#        'region': 'Asia',
#        'country': 'Qatar',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 16, 'text': '16'}],
#        'children': []}]},
#     {'label': 'Saudi Arabia',
#      'value': 'Saudi Arabia',
#      'region': 'Asia',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 130, 'text': '130'}],
#      'children': [{'label': 'Jeddah',
#        'value': 'Jeddah',
# ...
#         {'label': 'Pereira',
#          'value': 'Pereira',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Caldas',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Cauca',
#        'value': 'Cauca',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': [{'label': 'Popayan',
#          'value': 'Popayan',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Cesar',
#        'value': 'Cesar',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': [{'label': 'Valledupar',
#          'value': 'Valledupar',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cesar',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Choco',
#        'value': 'Choco',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': [{'label': 'Quibdo',
#          'value': 'Quibdo',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Choco',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Cordoba',
#        'value': 'Cordoba',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': [{'label': 'Monteria',
#          'value': 'Monteria',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cordoba',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Tierralta',
#          'value': 'Tierralta',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cordoba',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Cundinamarca',
#        'value': 'Cundinamarca',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 9, 'text': '9'}],
#        'children': [{'label': 'Cajica',
#          'value': 'Cajica',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cundinamarca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Choconta',
#          'value': 'Choconta',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cundinamarca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Funza',
#          'value': 'Funza',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cundinamarca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Madrid',
#          'value': 'Madrid',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cundinamarca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Pacho',
#          'value': 'Pacho',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cundinamarca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Soacha',
#          'value': 'Soacha',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cundinamarca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Zipaquira',
#          'value': 'Zipaquira',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Cundinamarca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []}]},
#       {'label': 'Huila',
#        'value': 'Huila',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 7, 'text': '7'}],
#        'children': [{'label': 'Neiva',
#          'value': 'Neiva',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Huila',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 7, 'text': '7'}],
#          'children': []}]},
#       {'label': 'Magdalena',
#        'value': 'Magdalena',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#        'children': [{'label': 'Cienaga',
#          'value': 'Cienaga',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Magdalena',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Santa Marta',
#          'value': 'Santa Marta',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Magdalena',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []}]},
#       {'label': 'Meta',
#        'value': 'Meta',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#        'children': [{'label': 'Villavicencio',
#          'value': 'Villavicencio',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Meta',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []}]},
#       {'label': 'Narino',
#        'value': 'Narino',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#        'children': [{'label': 'Ipiales',
#          'value': 'Ipiales',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Narino',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Tumaco',
#          'value': 'Tumaco',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Narino',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]},
#       {'label': 'Norte de Santander',
#        'value': 'Norte de Santander',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#        'children': [{'label': 'Cucuta',
#          'value': 'Cucuta',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Norte de Santander',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []}]},
#       {'label': 'Quindio',
#        'value': 'Quindio',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': [{'label': 'Armenia',
#          'value': 'Armenia',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Quindio',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []}]},
#       {'label': 'Risaralda',
#        'value': 'Risaralda',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 5, 'text': '5'}],
#        'children': [{'label': 'Dosquebradas',
#          'value': 'Dosquebradas',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Risaralda',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Pereira',
#          'value': 'Pereira',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Risaralda',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#          'children': []}]},
#       {'label': 'Santander',
#        'value': 'Santander',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#        'children': [{'label': 'Barrancabermeja',
#          'value': 'Barrancabermeja',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Santander',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Bucaramanga',
#          'value': 'Bucaramanga',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Santander',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []}]},
#       {'label': 'Tolima',
#        'value': 'Tolima',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#        'children': [{'label': 'Ibague',
#          'value': 'Ibague',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Tolima',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []}]},
#       {'label': 'Valle del Cauca',
#        'value': 'Valle del Cauca',
#        'region': 'South America',
#        'country': 'Colombia',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 47, 'text': '47'}],
#        'children': [{'label': 'Andalucia',
#          'value': 'Andalucia',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Ansermo',
#          'value': 'Ansermo',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Buga',
#          'value': 'Buga',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Cali',
#          'value': 'Cali',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 31, 'text': '31'}],
#          'children': []},
#         {'label': 'Cartago',
#          'value': 'Cartago',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'El Cerrito',
#          'value': 'El Cerrito',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#          'children': []},
#         {'label': 'Jamundi',
#          'value': 'Jamundi',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Palmira',
#          'value': 'Palmira',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Trujillo',
#          'value': 'Trujillo',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []},
#         {'label': 'Tulua',
#          'value': 'Tulua',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#          'children': []},
#         {'label': 'Yumbo',
#          'value': 'Yumbo',
#          'region': 'South America',
#          'country': 'Colombia',
#          'division': 'Valle del Cauca',
#          'level': 'location',
#          'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#          'children': []}]}]},
#     {'label': 'Ecuador',
#      'value': 'Ecuador',
#      'region': 'South America',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 4, 'text': '4'}],
#      'children': [{'label': 'Pichincha',
#        'value': 'Pichincha',
#        'region': 'South America',
#        'country': 'Ecuador',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 3, 'text': '3'}],
#        'children': []},
#       {'label': 'Quito',
#        'value': 'Quito',
#        'region': 'South America',
#        'country': 'Ecuador',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 1, 'text': '1'}],
#        'children': []}]},
#     {'label': 'Peru',
#      'value': 'Peru',
#      'region': 'South America',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#      'children': [{'label': 'Lima',
#        'value': 'Lima',
#        'region': 'South America',
#        'country': 'Peru',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 2, 'text': '2'}],
#        'children': []}]},
#     {'label': 'Uruguay',
#      'value': 'Uruguay',
#      'region': 'South America',
#      'level': 'country',
#      'actions': [{'className': 'fa fa-info', 'title': 45, 'text': '45'}],
#      'children': [{'label': 'Montevideo',
#        'value': 'Montevideo',
#        'region': 'South America',
#        'country': 'Uruguay',
#        'level': 'division',
#        'actions': [{'className': 'fa fa-info', 'title': 45, 'text': '45'}],
#        'children': []}]}]}]}
