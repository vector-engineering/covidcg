# %% [markdown]
# # Find a better way to clean locations, with less code

# %%
import json
import numpy as np
import networkx as nx
import pandas as pd
import re

from pathlib import Path

data_dir = Path('/Users/chena/covid_ui/data').resolve() # Resolve any symlinks --> absolute path
data_dir
# Out:
# PosixPath('/Volumes/GoogleDrive/My Drive/covid_data')

# %%
patient_meta_files = sorted((data_dir / 'patient_meta').glob('*.tsv'))
print('Collecting {} patient metadata files...'.format(len(patient_meta_files)), end='', flush=True)
patient_meta_df = pd.DataFrame()
for f in patient_meta_files:
    _df = pd.read_csv(f, sep='\t', skiprows=2)
    patient_meta_df = pd.concat([patient_meta_df, _df], ignore_index=True)

# Save dataframe
patient_meta_df.to_csv(data_dir / 'patient_meta.csv', index=False)
print('done', flush=True)

# Location data is stored in one column, "region / country / division / location"
location_df = (
    patient_meta_df['Location'].str.split('/', expand=True)
    .iloc[:, :4] # Only take 4 columns
    # Rename columns
    .rename(columns={0: 'region', 1: 'country', 2: 'division', 3: 'location'})
    .applymap(lambda x: x.strip() if x else x)
    # Placeholder for missing values, so that it will still 
    # be caught by groupby() later on
    .fillna(-1)
)
# Re-add metadata columns
location_df['name'] = patient_meta_df['Virus name']
location_df['gisaid_id'] = patient_meta_df['Accession ID']
location_df['sample_date'] = patient_meta_df['Collection date']

# Convert sample_date to datetime
location_df['sample_date'] = pd.to_datetime(location_df['sample_date'], yearfirst=True)
# Out:
# Collecting 14 patient metadata files...done

# %%
location_df
# Out:
#        region         country division location  \
# 0        Asia           China    Hubei    Wuhan
# 1        Asia           China    Hubei    Wuhan
# 2        Asia           China    Hubei    Wuhan
# 3        Asia           China    Hubei    Wuhan
# 4        Asia           China    Hubei    Wuhan
# ...       ...             ...      ...      ...
# 37392  Europe  United Kingdom  England       -1
# 37393  Europe  United Kingdom  England       -1
# 37394  Europe  United Kingdom  England       -1
# 37395  Europe  United Kingdom  England       -1
# 37396  Europe  United Kingdom  England       -1
#
#                                    name       gisaid_id sample_date
# 0         hCoV-19/Wuhan/IVDC-HB-01/2019  EPI_ISL_402119  2019-12-30
# 1         hCoV-19/Wuhan/IVDC-HB-04/2020  EPI_ISL_402120  2020-01-01
# 2         hCoV-19/Wuhan/IVDC-HB-05/2019  EPI_ISL_402121  2019-12-30
# 3      hCoV-19/Wuhan/IPBCAMS-WH-01/2019  EPI_ISL_402123  2019-12-24
# 4              hCoV-19/Wuhan/WIV04/2019  EPI_ISL_402124  2019-12-30
# ...                                 ...             ...         ...
# 37392   hCoV-19/England/NORW-EB900/2020  EPI_ISL_457455  2020-05-08
# 37393   hCoV-19/England/NORW-EB91F/2020  EPI_ISL_457456  2020-05-08
# 37394   hCoV-19/England/NORW-EB93D/2020  EPI_ISL_457457  2020-05-08
# 37395   hCoV-19/England/NORW-EB94C/2020  EPI_ISL_457458  2020-05-08
# 37396   hCoV-19/England/NORW-EB979/2020  EPI_ISL_457460  2020-05-06
#
# [37397 rows x 7 columns]

# %%
location_df.loc[
    (location_df['country'] == 'South Africa') &
    (location_df['division'] == 'EC'),
    :
]
# Out:
#        region       country division location  \
# 15691  Africa  South Africa       EC       -1
#
#                                    name       gisaid_id sample_date
# 15691  hCoV-19/South Africa/R05475/2020  EPI_ISL_435059  2020-03-20

# %%
# Make rules, which are mappings of input region/country/division/location -> output region/country/division/location

rules = [
    (
        {'country': 'South Africa', 'division': 'EC'}, # Input
        {'division': 'Eastern Cape'}  # Output
    )
]

# %%
from functools import reduce

# %%
reduce(lambda x, y: (x**2) + (y**2), [1, 2, 3, 4, 5])
# Out:
# 1373609

# %%
reduce(lambda x, y: (x**2) + (y**2), [3,])
# Out:
# 3

# %%
for rule in rules:
    # print(rule)
    input_rule = rule[0]
    output_rule = rule[1]
    
    # Get matching entries for the input rule
    # by creating a logical mask
    # Start out with matching everything
    loc_mask = pd.Series(np.repeat(True, len(location_df)))
    for key in input_rule.keys():
        vals = input_rule[key]
        # Make it a list if it's just a single value
        if type(vals) is not list:
            vals = [vals]
            
        # Turn each value into a logical mask
        vals = [location_df[key] == v for v in vals]
        # Combine logical masks with logical ORs, and merge into the master mask with AND
        loc_mask = (loc_mask & reduce(lambda x, y: (x | y), vals)) 
        
        # Set the output rules on the matching entries from loc_mask
        for okey in output_rule.keys():
            location_df.loc[loc_mask, okey] = output_rule[okey]
    
    print(location_df.loc[loc_mask, :])
# Out:
# Empty DataFrame
# Columns: [region, country, division, location, name, gisaid_id, sample_date]
# Index: []

# %%
location_df.loc[
    (location_df['country'] == 'South Africa') &
    (location_df['division'] == 'EC'),
    :
]
# Out:
# Empty DataFrame
# Columns: [region, country, division, location, name, gisaid_id, sample_date]
# Index: []

# %%
location_df.loc[
    (location_df['country'] == 'South Africa') &
    (location_df['division'] == 'Eastern Cape'),
    :
]
# Out:
#        region       country      division location  \
# 534    Africa  South Africa  Eastern Cape       -1
# 7909   Africa  South Africa  Eastern Cape       -1
# 7910   Africa  South Africa  Eastern Cape       -1
# 7911   Africa  South Africa  Eastern Cape       -1
# 7912   Africa  South Africa  Eastern Cape       -1
# 7913   Africa  South Africa  Eastern Cape       -1
# 11279  Africa  South Africa  Eastern Cape       -1
# 15690  Africa  South Africa  Eastern Cape       -1
# 15691  Africa  South Africa  Eastern Cape       -1
# 16329  Africa  South Africa  Eastern Cape       -1
# 16330  Africa  South Africa  Eastern Cape       -1
# 16331  Africa  South Africa  Eastern Cape       -1
# 16332  Africa  South Africa  Eastern Cape       -1
# 30147  Africa  South Africa  Eastern Cape       -1
# 30148  Africa  South Africa  Eastern Cape       -1
# 30149  Africa  South Africa  Eastern Cape       -1
# 30150  Africa  South Africa  Eastern Cape       -1
# 30998  Africa  South Africa  Eastern Cape       -1
# 30999  Africa  South Africa  Eastern Cape       -1
# 31092  Africa  South Africa  Eastern Cape       -1
# 35608  Africa  South Africa  Eastern Cape       -1
# 35609  Africa  South Africa  Eastern Cape       -1
# 35610  Africa  South Africa  Eastern Cape       -1
# 35611  Africa  South Africa  Eastern Cape       -1
# 35612  Africa  South Africa  Eastern Cape       -1
# 35613  Africa  South Africa  Eastern Cape       -1
